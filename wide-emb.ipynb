# %%
from operator import itemgetter

import numpy as np

# %%
def LoadEmbedding(fname):
    with open(fname, 'r') as f:
        lines = f.readlines()
    lines = [line.strip() for line in lines]
    return lines


def LoadEdges(fname):
    with open(fname, 'r') as f:
        lines = f.readlines()
    lines = [line.strip() for line in lines]
    return lines

# %%
# Hyperbolic distance between two points

def dist(u, v):
    z = 2 * np.linalg.norm(u - v) ** 2
    uu = 1
    nu = np.linalg.norm(u)
    nv = np.linalg.norm(v)
    if nu != 1 and nv != 1:
        uu = 1. + z/((1-nu**2)*(1-nv**2))
    return np.arccosh(uu)

# %%
def ProcessEmbeddings(emb, dim):
    emb = emb[1:]
    embDict = dict()
    tau = 0.0
    for it, line in enumerate(emb):
        lst = line.split(',')
        currTau = np.float64(lst[-1])
        idx = np.int64(lst[0])
        embDict[idx] = np.asarray(lst[1:-1], dtype=np.float64)
        assert embDict[idx].shape[0] == dim
        tau = currTau
    return embDict, tau


def BuildWMatrix(embDict, dim):
    vocabSize = len(embDict)
    W = np.zeros((vocabSize, dim), dtype=np.float64)
    for idx, emb in embDict.items():
        W[idx, :] = emb
    return W, vocabSize

# %%
def build(femb, dim, key):
    emb = LoadEmbedding(femb)
    embDict, tau = ProcessEmbeddings(emb, dim)
    print(f"tau={tau}")
    W, vocabSize = BuildWMatrix(embDict, dim)

    word = key
    d = []
    wvec = embDict[word]
    for idx in range(W.shape[0]):
        vec = W[idx, :]
        if not np.equal(vec, wvec).all():
            d.append((idx, dist(wvec, vec) / tau))
    print()
    print()
    print(f"Relations for {word} in embedding using distance metric")
    bestMatches = []
    for k, v in sorted(d, key=itemgetter(1))[:5]:
        print(f"{k} {v}")
        bestMatches.append(k)
    print()
    print()
    return bestMatches

# %%
for j in range(2, 1000):
    bm = build('data/emb/1000r2.emb', 2, j)
    assert(bm[0] == 1)
# Out:
# tau=17.328679513998633
#
#
# Relations for 2 in embedding using distance metric
# 1 0.9999999862428434
# 3 1.3349722032203768
# 0 1.3349722169562068
# 4 1.414971584988843
# 999 1.4149716324963437
#
#
# tau=17.328679513998633
#
#
# Relations for 3 in embedding using distance metric
# 1 0.9999999862641693
# 4 1.3349721557128762
# 2 1.3349722032203768
# 5 1.4149716326337285
# 0 1.4149716462748296
#
#
# tau=17.328679513998633
#
#
# Relations for 4 in embedding using distance metric
# 1 0.9999999387353377
# 3 1.3349721557128762
# 5 1.3349721558076049
# 6 1.4149709432704947
# 2 1.414971584988843
#
#
# tau=17.328679513998633
#
#
# Relations for 5 in embedding using distance metric
# 1 0.999999986358898
# 6 1.3349715615967575
# 4 1.3349721558076049
# 7 1.4149715855692004
# 3 1.4149716326337285
#
#
# tau=17.328679513998633
#
#
# Relations for 6 in embedding using distance metric
# 1 0.999999344524508
# 7 1.3349715144375007
# 5 1.3349715615967575
# 8 1.4149704211045433
# 4 1.4149709432704947
#
#
# tau=17.328679513998633
#
#
# Relations for 7 in embedding using distance metric
# 1 0.9999999391996383
# 6 1.3349715144375007
# 8 1.3349715864823968
# 5 1.4149715855692004
# 9 1.4149715870169919
#
#
# tau=17.328679513998633
#
#
# Relations for 8 in embedding using distance metric
# 1 0.9999994165694591
# 7 1.3349715864823968
# 9 1.3349716350894447
# 10 1.4149693061720172
# 6 1.4149704211045433
#
#
# tau=17.328679513998633
#
#
# Relations for 9 in embedding using distance metric
# 1 0.9999999878066895
# 10 1.3349704481120233
# 8 1.3349716350894447
# 11 1.4149692132480385
# 7 1.4149715870169919
#
#
# tau=17.328679513998633
#
#
# Relations for 10 in embedding using distance metric
# 1 0.9999982295920343
# 11 1.3349680257360217
# 9 1.3349704481120233
# 12 1.4149672786848109
# 8 1.4149693061720172
#
#
# tau=17.328679513998633
#
#
# Relations for 11 in embedding using distance metric
# 1 0.9999975654307559
# 12 1.3349671852262377
# 10 1.3349680257360217
# 13 1.4149678885390933
# 9 1.4149692132480385
#
#
# tau=17.328679513998633
#
#
# Relations for 12 in embedding using distance metric
# 1 0.999997389082285
# 11 1.3349671852262377
# 13 1.3349682828932938
# 14 1.4149672280613976
# 10 1.4149672786848109
#
#
# tau=17.328679513998633
#
#
# Relations for 13 in embedding using distance metric
# 1 0.9999986630979711
# 12 1.3349682828932938
# 14 1.3349690727796644
# 11 1.4149678885390933
# 15 1.4149697535070482
#
#
# tau=17.328679513998633
#
#
# Relations for 14 in embedding using distance metric
# 1 0.999998178968805
# 13 1.3349690727796644
# 15 1.3349698400805632
# 12 1.4149672280613976
# 16 1.4149697967703496
#
#
# tau=17.328679513998633
#
#
# Relations for 15 in embedding using distance metric
# 1 0.99999943039861
# 14 1.3349698400805632
# 16 1.3349716189031442
# 17 1.414964259184994
# 13 1.4149697535070482
#
#
# tau=17.328679513998633
#
#
# Relations for 16 in embedding using distance metric
# 1 0.9999999577911333
# 17 1.334965357280192
# 15 1.3349716189031442
# 18 1.4149675020429346
# 14 1.4149697967703496
#
#
# tau=17.328679513998633
#
#
# Relations for 17 in embedding using distance metric
# 1 0.9999931687758269
# 18 1.3349612837301963
# 16 1.334965357280192
# 19 1.4149630968043938
# 15 1.414964259184994
#
#
# tau=17.328679513998633
#
#
# Relations for 18 in embedding using distance metric
# 1 0.9999958842415074
# 17 1.3349612837301963
# 19 1.3349663829725482
# 16 1.4149675020429346
# 20 1.4149681851791192
#
#
# tau=17.328679513998633
#
#
# Relations for 19 in embedding using distance metric
# 1 0.9999982680179403
# 18 1.3349663829725482
# 20 1.3349711396587292
# 17 1.4149630968043938
# 21 1.4149711143648878
#
#
# tau=17.328679513998633
#
#
# Relations for 20 in embedding using distance metric
# 1 1.0000006409273587
# 19 1.3349711396587292
# 21 1.3349740579768699
# 18 1.4149681851791192
# 22 1.4149729539524365
#
#
# tau=17.328679513998633
#
#
# Relations for 21 in embedding using distance metric
# 1 1.0000011863362552
# 20 1.3349740579768699
# 22 1.3349740700640051
# 19 1.4149711143648878
# 23 1.4149746300775925
#
#
# tau=17.328679513998633
#
#
# Relations for 22 in embedding using distance metric
# 1 1.0000006530144954
# 21 1.3349740700640051
# 23 1.3349746674585692
# 24 1.4149675622571136
# 20 1.4149729539524365
#
#
# tau=17.328679513998633
#
#
# Relations for 23 in embedding using distance metric
# 1 1.0000017837308546
# 24 1.334969263676111
# 22 1.3349746674585692
# 21 1.4149746300775925
# 25 1.4149773522788145
#
#
# tau=17.328679513998633
#
#
# Relations for 24 in embedding using distance metric
# 1 0.999995249232837
# 23 1.334969263676111
# 25 1.3349713884827692
# 26 1.414966401642798
# 22 1.4149675622571136
#
#
# tau=17.328679513998633
#
#
# Relations for 25 in embedding using distance metric
# 1 1.0000039085376398
# 24 1.3349713884827692
# 26 1.3349756316509116
# 27 1.41496789751842
# 23 1.4149773522788145
#
#
# tau=17.328679513998633
#
#
# Relations for 26 in embedding using distance metric
# 1 0.9999994924001107
# 27 1.3349640520838608
# 25 1.3349756316509116
# 28 1.4149628584546698
# 24 1.414966401642798
#
#
# tau=17.328679513998633
#
#
# Relations for 27 in embedding using distance metric
# 1 0.9999923289713303
# 28 1.33495626572759
# 26 1.3349640520838608
# 29 1.414963637013801
# 25 1.41496789751842
#
#
# tau=17.328679513998633
#
#
# Relations for 28 in embedding using distance metric
# 1 0.9999917060449205
# 27 1.33495626572759
# 29 1.3349635847900223
# 26 1.4149628584546698
# 30 1.4149669973128396
#
#
# tau=17.328679513998633
#
#
# Relations for 29 in embedding using distance metric
# 1 0.9999996480327669
# 28 1.3349635847900223
# 30 1.3349755100044636
# 27 1.414963637013801
# 31 1.4149715512231194
#
#
# tau=17.328679513998633
#
#
# Relations for 30 in embedding using distance metric
# 1 1.0000036312585274
# 29 1.3349755100044636
# 31 1.3349761051513467
# 28 1.4149669973128396
# 32 1.414971891247779
#
#
# tau=17.328679513998633
#
#
# Relations for 31 in embedding using distance metric
# 1 1.0000002431796864
# 32 1.3349690738718454
# 30 1.3349761051513467
# 33 1.4149472627071933
# 29 1.4149715512231194
#
#
# tau=17.328679513998633
#
#
# Relations for 32 in embedding using distance metric
# 1 0.999996599978606
# 33 1.3349441902090395
# 31 1.3349690738718454
# 34 1.4149689641522754
# 30 1.414971891247779
#
#
# tau=17.328679513998633
#
#
# Relations for 33 in embedding using distance metric
# 1 0.9999753595175618
# 32 1.3349441902090395
# 34 1.334948294393037
# 35 1.4149433859674552
# 31 1.4149472627071933
#
#
# tau=17.328679513998633
#
#
# Relations for 34 in embedding using distance metric
# 1 1.0000007041628487
# 33 1.334948294393037
# 35 1.3349693013161053
# 32 1.4149689641522754
# 36 1.4149758270333948
#
#
# tau=17.328679513998633
#
#
# Relations for 35 in embedding using distance metric
# 1 0.9999963664397166
# 34 1.3349693013161053
# 36 1.3349720600132267
# 33 1.4149433859674552
# 37 1.414955385305278
#
#
# tau=17.328679513998633
#
#
# Relations for 36 in embedding using distance metric
# 1 1.0000034628601349
# 37 1.3349630524279794
# 35 1.3349720600132267
# 34 1.4149758270333948
# 38 1.4149828082188927
#
#
# tau=17.328679513998633
#
#
# Relations for 37 in embedding using distance metric
# 1 0.9999873588566746
# 36 1.3349630524279794
# 38 1.3349672749163555
# 39 1.4149475772882802
# 35 1.414955385305278
#
#
# tau=17.328679513998633
#
#
# Relations for 38 in embedding using distance metric
# 1 1.000007685348763
# 37 1.3349672749163555
# 39 1.3349684744846049
# 40 1.4149823884720056
# 36 1.4149828082188927
#
#
# tau=17.328679513998633
#
#
# Relations for 39 in embedding using distance metric
# 1 0.9999885584222532
# 40 1.3349638322493438
# 38 1.3349684744846049
# 41 1.4149339221784487
# 37 1.4149475772882802
#
#
# tau=17.328679513998633
#
#
# Relations for 40 in embedding using distance metric
# 1 1.0000030431132232
# 41 1.3349489775712629
# 39 1.3349638322493438
# 42 1.4149635485825418
# 38 1.4149823884720056
#
#
# tau=17.328679513998633
#
#
# Relations for 41 in embedding using distance metric
# 1 0.999973703746668
# 42 1.3349347799170632
# 40 1.3349489775712629
# 43 1.414915838906881
# 39 1.4149339221784487
#
#
# tau=17.328679513998633
#
#
# Relations for 42 in embedding using distance metric
# 1 0.9999888454581755
# 43 1.33493155132358
# 41 1.3349347799170632
# 44 1.4149189281701406
# 40 1.4149635485825418
#
#
# tau=17.328679513998633
#
#
# Relations for 43 in embedding using distance metric
# 1 0.9999704751533354
# 44 1.3349011285653827
# 42 1.33493155132358
# 41 1.414915838906881
# 45 1.4149452283068074
#
#
# tau=17.328679513998633
#
#
# Relations for 44 in embedding using distance metric
# 1 0.999958422702066
# 43 1.3349011285653827
# 45 1.3349337465587894
# 46 1.4148810910672451
# 42 1.4149189281701406
#
#
# tau=17.328679513998633
#
#
# Relations for 45 in embedding using distance metric
# 1 1.0000030931449637
# 46 1.3349263322140952
# 44 1.3349337465587894
# 43 1.4149452283068074
# 47 1.4149716009578852
#
#
# tau=17.328679513998633
#
#
# Relations for 46 in embedding using distance metric
# 1 0.9999510083572989
# 47 1.334920086871765
# 45 1.3349263322140952
# 44 1.4148810910672451
# 48 1.414904586488577
#
#
# tau=17.328679513998633
#
#
# Relations for 47 in embedding using distance metric
# 1 0.9999968478022584
# 46 1.334920086871765
# 48 1.3349509966377848
# 49 1.4149334911698512
# 45 1.4149716009578852
#
#
# tau=17.328679513998633
#
#
# Relations for 48 in embedding using distance metric
# 1 0.9999819181208927
# 49 1.334919132192089
# 47 1.3349509966377848
# 46 1.414904586488577
# 50 1.414970766573395
#
#
# tau=17.328679513998633
#
#
# Relations for 49 in embedding using distance metric
# 1 0.9999649833595168
# 48 1.334919132192089
# 50 1.3349544025108757
# 51 1.4148941308617466
# 47 1.4149334911698512
#
#
# tau=17.328679513998633
#
#
# Relations for 50 in embedding using distance metric
# 1 1.0000171884417886
# 51 1.3349469066484734
# 49 1.3349544025108757
# 52 1.4149327868260873
# 48 1.414970766573395
#
#
# tau=17.328679513998633
#
#
# Relations for 51 in embedding using distance metric
# 1 0.9999574874970769
# 52 1.3348736565823847
# 50 1.3349469066484734
# 49 1.4148941308617466
# 53 1.4149002043467116
#
#
# tau=17.328679513998633
#
#
# Relations for 52 in embedding using distance metric
# 1 0.9999439383768015
# 51 1.3348736565823847
# 53 1.3348872259297508
# 54 1.4148493828541289
# 50 1.4149327868260873
#
#
# tau=17.328679513998633
#
#
# Relations for 53 in embedding using distance metric
# 1 0.9999710568456804
# 54 1.3348770720238912
# 52 1.3348872259297508
# 51 1.4149002043467116
# 55 1.4149632238218108
#
#
# tau=17.328679513998633
#
#
# Relations for 54 in embedding using distance metric
# 1 0.9999337844707697
# 53 1.3348770720238912
# 55 1.3349265221516184
# 52 1.4148493828541289
# 56 1.414927647273092
#
#
# tau=17.328679513998633
#
#
# Relations for 55 in embedding using distance metric
# 1 1.0000205069706645
# 54 1.3349265221516184
# 56 1.3350149404764278
# 57 1.4149122957976286
# 53 1.4149632238218108
#
#
# tau=17.328679513998633
#
#
# Relations for 56 in embedding using distance metric
# 1 1.0000222027949508
# 57 1.334914562324526
# 55 1.3350149404764278
# 58 1.4149177686976553
# 54 1.414927647273092
#
#
# tau=17.328679513998633
#
#
# Relations for 57 in embedding using distance metric
# 1 0.9999201288193587
# 58 1.3348162654242828
# 56 1.334914562324526
# 59 1.4148104191430593
# 55 1.4149122957976286
#
#
# tau=17.328679513998633
#
#
# Relations for 58 in embedding using distance metric
# 1 0.9999239058956612
# 59 1.3348147669216273
# 57 1.3348162654242828
# 60 1.4149139799503299
# 56 1.4149177686976553
#
#
# tau=17.328679513998633
#
#
# Relations for 59 in embedding using distance metric
# 1 0.9999186303170879
# 58 1.3348147669216273
# 60 1.3349092750745468
# 57 1.4148104191430593
# 61 1.4148633596773896
#
#
# tau=17.328679513998633
#
#
# Relations for 60 in embedding using distance metric
# 1 1.0000184140473989
# 59 1.3349092750745468
# 61 1.3349637141115236
# 58 1.4149139799503299
# 62 1.4150129986482567
#
#
# tau=17.328679513998633
#
#
# Relations for 61 in embedding using distance metric
# 1 0.9999730693502511
# 60 1.3349637141115236
# 62 1.3349682246565209
# 63 1.4148450912967114
# 59 1.4148633596773896
#
#
# tau=17.328679513998633
#
#
# Relations for 62 in embedding using distance metric
# 1 1.0000229245926635
# 63 1.3348955172388641
# 61 1.3349682246565209
# 64 1.414995869400764
# 60 1.4150129986482567
#
#
# tau=17.328679513998633
#
#
# Relations for 63 in embedding using distance metric
# 1 0.9999003619363145
# 64 1.3348738774463804
# 62 1.3348955172388641
# 65 1.4147815062760647
# 61 1.4148450912967114
#
#
# tau=17.328679513998633
#
#
# Relations for 64 in embedding using distance metric
# 1 1.0000012847988853
# 63 1.3348738774463804
# 65 1.3348829998433966
# 66 1.4148708947759683
# 62 1.414995869400764
#
#
# tau=17.328679513998633
#
#
# Relations for 65 in embedding using distance metric
# 1 0.9999094843343989
# 66 1.3347796650111015
# 64 1.3348829998433966
# 63 1.4147815062760647
# 67 1.4148502061528299
#
#
# tau=17.328679513998633
#
#
# Relations for 66 in embedding using distance metric
# 1 0.9998979499692658
# 65 1.3347796650111015
# 67 1.3348392424908433
# 68 1.4148372759449825
# 64 1.4148708947759683
#
#
# tau=17.328679513998633
#
#
# Relations for 67 in embedding using distance metric
# 1 0.9999690618091134
# 66 1.3348392424908433
# 68 1.334908958492154
# 69 1.414822910728918
# 65 1.4148502061528299
#
#
# tau=17.328679513998633
#
#
# Relations for 68 in embedding using distance metric
# 1 0.9999676659658933
# 69 1.3348220855885073
# 67 1.334908958492154
# 66 1.4148372759449825
# 70 1.4149739634935614
#
#
# tau=17.328679513998633
#
#
# Relations for 69 in embedding using distance metric
# 1 0.9998821889099467
# 68 1.3348220855885073
# 70 1.3348890571357555
# 71 1.4147797335255803
# 67 1.414822910728918
#
#
# tau=17.328679513998633
#
#
# Relations for 70 in embedding using distance metric
# 1 1.000034637517144
# 69 1.3348890571357555
# 71 1.334932752836069
# 72 1.4148887887488526
# 68 1.4149739634935614
#
#
# tau=17.328679513998633
#
#
# Relations for 71 in embedding using distance metric
# 1 0.9999258846134469
# 72 1.3347806065441243
# 70 1.334932752836069
# 69 1.4147797335255803
# 73 1.414803655310386
#
#
# tau=17.328679513998633
#
#
# Relations for 72 in embedding using distance metric
# 1 0.9998824912266392
# 73 1.3347608326286167
# 71 1.3347806065441243
# 74 1.4148527740372776
# 70 1.4148887887488526
#
#
# tau=17.328679513998633
#
#
# Relations for 73 in embedding using distance metric
# 1 0.9999061106973353
# 72 1.3347608326286167
# 74 1.3348769642089846
# 71 1.414803655310386
# 75 1.4148478871300574
#
#
# tau=17.328679513998633
#
#
# Relations for 74 in embedding using distance metric
# 1 0.9999986228034202
# 73 1.3348769642089846
# 75 1.334940969944164
# 72 1.4148527740372776
# 76 1.4149741348827272
#
#
# tau=17.328679513998633
#
#
# Relations for 75 in embedding using distance metric
# 1 0.9999701164255089
# 74 1.334940969944164
# 76 1.3349461992092246
# 77 1.4148411768469051
# 73 1.4148478871300574
#
#
# tau=17.328679513998633
#
#
# Relations for 76 in embedding using distance metric
# 1 1.000003852068795
# 77 1.3348754831908969
# 75 1.3349461992092246
# 78 1.4148254096254917
# 74 1.4149741348827272
#
#
# tau=17.328679513998633
#
#
# Relations for 77 in embedding using distance metric
# 1 0.9998994004149958
# 78 1.33472152866862
# 76 1.3348754831908969
# 79 1.414727645821372
# 75 1.4148411768469051
#
#
# tau=17.328679513998633
#
#
# Relations for 78 in embedding using distance metric
# 1 0.9998498975496626
# 79 1.33467871366143
# 77 1.33472152866862
# 80 1.414742420656354
# 76 1.4148254096254917
#
#
# tau=17.328679513998633
#
#
# Relations for 79 in embedding using distance metric
# 1 0.9998565854058703
# 78 1.33467871366143
# 80 1.3347496792145808
# 77 1.414727645821372
# 81 1.4148725461125824
#
#
# tau=17.328679513998633
#
#
# Relations for 80 in embedding using distance metric
# 1 0.9999208631077007
# 79 1.3347496792145808
# 81 1.334937394512961
# 78 1.414742420656354
# 82 1.4148917233515323
#
#
# tau=17.328679513998633
#
#
# Relations for 81 in embedding using distance metric
# 1 1.0000443007028053
# 80 1.334937394512961
# 82 1.3350157316549676
# 79 1.4148725461125824
# 83 1.4150207618954562
#
#
# tau=17.328679513998633
#
#
# Relations for 82 in embedding using distance metric
# 1 0.9999992002413985
# 83 1.3349762321394443
# 81 1.3350157316549676
# 84 1.4147932039948103
# 80 1.4148917233515323
#
#
# tau=17.328679513998633
#
#
# Relations for 83 in embedding using distance metric
# 1 1.0000048011849199
# 84 1.3347993756407257
# 82 1.3349762321394443
# 85 1.4149033768454613
# 81 1.4150207618954562
#
#
# tau=17.328679513998633
#
#
# Relations for 84 in embedding using distance metric
# 1 0.999822343746408
# 85 1.3347214901062727
# 83 1.3347993756407257
# 86 1.41462841562694
# 82 1.4147932039948103
#
#
# tau=17.328679513998633
#
#
# Relations for 85 in embedding using distance metric
# 1 0.9999269156604611
# 84 1.3347214901062727
# 86 1.3347335582371396
# 83 1.4149033768454613
# 87 1.4149411746339513
#
#
# tau=17.328679513998633
#
#
# Relations for 86 in embedding using distance metric
# 1 0.9998344118786817
# 85 1.3347335582371396
# 87 1.3348492415600812
# 84 1.41462841562694
# 88 1.4148501595867462
#
#
# tau=17.328679513998633
#
#
# Relations for 87 in embedding using distance metric
# 1 1.0000425989756634
# 86 1.3348492415600812
# 88 1.335058917388987
# 89 1.4148365250134594
# 85 1.4149411746339513
#
#
# tau=17.328679513998633
#
#
# Relations for 88 in embedding using distance metric
# 1 1.0000440877051395
# 89 1.3348385844455695
# 87 1.335058917388987
# 86 1.4148501595867462
# 90 1.4149256081450414
#
#
# tau=17.328679513998633
#
#
# Relations for 89 in embedding using distance metric
# 1 0.9998222660351073
# 90 1.334704357174951
# 88 1.3348385844455695
# 87 1.4148365250134594
# 91 1.414839062579502
#
#
# tau=17.328679513998633
#
#
# Relations for 90 in embedding using distance metric
# 1 0.9999098604428953
# 89 1.334704357174951
# 91 1.3349272276844066
# 92 1.414823089051657
# 88 1.4149256081450414
#
#
# tau=17.328679513998633
#
#
# Relations for 91 in embedding using distance metric
# 1 1.0000451365418552
# 90 1.3349272276844066
# 92 1.3349589358616551
# 89 1.414839062579502
# 93 1.4148919807818612
#
#
# tau=17.328679513998633
#
#
# Relations for 92 in embedding using distance metric
# 1 0.9999415686056397
# 93 1.3347889835545554
# 91 1.3349589358616551
# 94 1.414759848675593
# 90 1.414823089051657
#
#
# tau=17.328679513998633
#
#
# Relations for 93 in embedding using distance metric
# 1 0.9998751842420829
# 94 1.3346940350012464
# 92 1.3347889835545554
# 95 1.414703425575798
# 91 1.4148919807818612
#
#
# tau=17.328679513998633
#
#
# Relations for 94 in embedding using distance metric
# 1 0.9998466200645143
# 95 1.3346754321023115
# 93 1.3346940350012464
# 96 1.4147241266217911
# 92 1.414759848675593
#
#
# tau=17.328679513998633
#
#
# Relations for 95 in embedding using distance metric
# 1 0.9998565813427791
# 94 1.3346754321023115
# 96 1.3347346586018223
# 93 1.414703425575798
# 97 1.414823514003094
#
#
# tau=17.328679513998633
#
#
# Relations for 96 in embedding using distance metric
# 1 0.9999058465683268
# 95 1.3347346586018223
# 97 1.3348733499280359
# 98 1.4146781922101577
# 94 1.4147241266217911
#
#
# tau=17.328679513998633
#
#
# Relations for 97 in embedding using distance metric
# 1 0.9999952726590532
# 98 1.3347681890169012
# 96 1.3348733499280359
# 95 1.414823514003094
# 99 1.4149327852711517
#
#
# tau=17.328679513998633
#
#
# Relations for 98 in embedding using distance metric
# 1 0.9998006856516559
# 99 1.3347387689587291
# 97 1.3347681890169012
# 100 1.414607812924188
# 96 1.4146781922101577
#
#
# tau=17.328679513998633
#
#
# Relations for 99 in embedding using distance metric
# 1 0.9999658525991196
# 98 1.3347387689587291
# 100 1.3347735505839018
# 97 1.4149327852711517
# 101 1.415017048662006
#
#
# tau=17.328679513998633
#
#
# Relations for 100 in embedding using distance metric
# 1 0.9998354672796974
# 99 1.3347735505839018
# 101 1.33488723403292
# 98 1.414607812924188
# 102 1.4148228249739123
#
#
# tau=17.328679513998633
#
#
# Relations for 101 in embedding using distance metric
# 1 1.0000795360549295
# 100 1.33488723403292
# 102 1.3350674644574378
# 99 1.415017048662006
# 103 1.4150340719087513
#
#
# tau=17.328679513998633
#
#
# Relations for 102 in embedding using distance metric
# 1 1.0000156976948353
# 103 1.3349708042551685
# 101 1.3350674644574378
# 100 1.4148228249739123
# 104 1.41496893418608
#
#
# tau=17.328679513998633
#
#
# Relations for 103 in embedding using distance metric
# 1 0.9999828758468825
# 104 1.334936683042794
# 102 1.3349708042551685
# 105 1.4149668896137035
# 101 1.4150340719087513
#
#
# tau=17.328679513998633
#
#
# Relations for 104 in embedding using distance metric
# 1 0.9999815764804229
# 103 1.334936683042794
# 105 1.3349661609500285
# 102 1.41496893418608
# 106 1.4150290495348843
#
#
# tau=17.328679513998633
#
#
# Relations for 105 in embedding using distance metric
# 1 1.0000123537558767
# 104 1.3349661609500285
# 106 1.335060397511195
# 107 1.4147706212559956
# 103 1.4149668896137035
#
#
# tau=17.328679513998633
#
#
# Relations for 106 in embedding using distance metric
# 1 1.0000758130472216
# 107 1.3348346512462814
# 105 1.335060397511195
# 108 1.4149570373736915
# 104 1.4150290495348843
#
#
# tau=17.328679513998633
#
#
# Relations for 107 in embedding using distance metric
# 1 0.99978660750046
# 108 1.3346684025239313
# 106 1.3348346512462814
# 105 1.4147706212559956
# 109 1.4148252990823371
#
#
# tau=17.328679513998633
#
#
# Relations for 108 in embedding using distance metric
# 1 0.999909564314932
# 107 1.3346684025239313
# 109 1.3349488266151825
# 110 1.414733229570679
# 106 1.4149570373736915
#
#
# tau=17.328679513998633
#
#
# Relations for 109 in embedding using distance metric
# 1 1.0000670315854765
# 110 1.3348912675345423
# 108 1.3349488266151825
# 107 1.4148252990823371
# 111 1.4151109013658834
#
#
# tau=17.328679513998633
#
#
# Relations for 110 in embedding using distance metric
# 1 0.9998520052551334
# 109 1.3348912675345423
# 111 1.3348964457268073
# 112 1.4147301258952467
# 108 1.414733229570679
#
#
# tau=17.328679513998633
#
#
# Relations for 111 in embedding using distance metric
# 1 1.0000722097780477
# 110 1.3348964457268073
# 112 1.3349509011320078
# 113 1.4148066388326372
# 109 1.4151109013658834
#
#
# tau=17.328679513998633
#
#
# Relations for 112 in embedding using distance metric
# 1 0.9999064606393167
# 113 1.334641460406547
# 111 1.3349509011320078
# 110 1.4147301258952467
# 114 1.4149549890978195
#
#
# tau=17.328679513998633
#
#
# Relations for 113 in embedding using distance metric
# 1 0.9997627690596399
# 112 1.334641460406547
# 114 1.3348118682038825
# 115 1.4147190193969688
# 111 1.4148066388326372
#
#
# tau=17.328679513998633
#
#
# Relations for 114 in embedding using distance metric
# 1 1.0000768684468393
# 113 1.3348118682038825
# 115 1.335033689493684
# 112 1.4149549890978195
# 116 1.4149637725978819
#
#
# tau=17.328679513998633
#
#
# Relations for 115 in embedding using distance metric
# 1 0.9999845903371538
# 116 1.334872065196418
# 114 1.335033689493684
# 113 1.4147190193969688
# 117 1.4148253568723332
#
#
# tau=17.328679513998633
#
#
# Relations for 116 in embedding using distance metric
# 1 0.9999152441399067
# 117 1.3347565813819613
# 115 1.334872065196418
# 118 1.4147333829070434
# 114 1.4149637725978819
#
#
# tau=17.328679513998633
#
#
# Relations for 117 in embedding using distance metric
# 1 0.9998691065431438
# 118 1.3346878159884192
# 116 1.3347565813819613
# 119 1.4146884544656197
# 115 1.4148253568723332
#
#
# tau=17.328679513998633
#
#
# Relations for 118 in embedding using distance metric
# 1 0.99984647877006
# 119 1.3346663973961828
# 117 1.3346878159884192
# 120 1.414691227079411
# 116 1.4147333829070434
#
#
# tau=17.328679513998633
#
#
# Relations for 119 in embedding using distance metric
# 1 0.9998476879505322
# 118 1.3346663973961828
# 120 1.3346930069620992
# 117 1.4146884544656197
# 121 1.4147424107093327
#
#
# tau=17.328679513998633
#
#
# Relations for 120 in embedding using distance metric
# 1 0.9998730883384835
# 119 1.3346930069620992
# 121 1.3347683817980378
# 118 1.414691227079411
# 122 1.4148427726643769
#
#
# tau=17.328679513998633
#
#
# Relations for 121 in embedding using distance metric
# 1 0.9999230627627207
# 120 1.3347683817980378
# 122 1.3348933178170734
# 119 1.4147424107093327
# 123 1.4149931408014953
#
#
# tau=17.328679513998633
#
#
# Relations for 122 in embedding using distance metric
# 1 0.9999980243362641
# 121 1.3348933178170734
# 123 1.335068673073255
# 124 1.4146814454204546
# 120 1.4148427726643769
#
#
# tau=17.328679513998633
#
#
# Relations for 123 in embedding using distance metric
# 1 1.0000984180293868
# 124 1.334782409810324
# 122 1.335068673073255
# 125 1.4149252850720173
# 121 1.4149931408014953
#
#
# tau=17.328679513998633
#
#
# Relations for 124 in embedding using distance metric
# 1 0.9997117610867692
# 125 1.3345391988246749
# 123 1.334782409810324
# 122 1.4146814454204546
# 126 1.4147087106871443
#
#
# tau=17.328679513998633
#
#
# Relations for 125 in embedding using distance metric
# 1 0.9998552070602545
# 124 1.3345391988246749
# 126 1.334852727354287
# 127 1.4145126298089152
# 123 1.4149252850720173
#
#
# tau=17.328679513998633
#
#
# Relations for 126 in embedding using distance metric
# 1 1.0000252896045794
# 127 1.3346832830768947
# 125 1.334852727354287
# 124 1.4147087106871443
# 128 1.4148976572902168
#
#
# tau=17.328679513998633
#
#
# Relations for 127 in embedding using distance metric
# 1 0.9996857627736473
# 128 1.334558701150327
# 126 1.3346832830768947
# 129 1.4142489398533795
# 125 1.4145126298089152
#
#
# tau=17.328679513998633
#
#
# Relations for 128 in embedding using distance metric
# 1 0.9999007076705582
# 129 1.3344644554722178
# 127 1.334558701150327
# 130 1.4147249340593577
# 126 1.4148976572902168
#
#
# tau=17.328679513998633
#
#
# Relations for 129 in embedding using distance metric
# 1 0.9995915170908395
# 130 1.3344163141679553
# 128 1.3344644554722178
# 127 1.4142489398533795
# 131 1.414705884058565
#
#
# tau=17.328679513998633
#
#
# Relations for 130 in embedding using distance metric
# 1 0.999852566396886
# 129 1.3344163141679553
# 131 1.3349675040511801
# 132 1.4147069469370384
# 128 1.4147249340593577
#
#
# tau=17.328679513998633
#
#
# Relations for 131 in embedding using distance metric
# 1 1.0001427069741051
# 130 1.3349675040511801
# 132 1.3349976582331309
# 129 1.414705884058565
# 133 1.4147499915756707
#
#
# tau=17.328679513998633
#
#
# Relations for 132 in embedding using distance metric
# 1 0.9998827205471653
# 133 1.3344905758670078
# 131 1.3349976582331309
# 130 1.4147069469370384
# 134 1.4148476956135727
#
#
# tau=17.328679513998633
#
#
# Relations for 133 in embedding using distance metric
# 1 0.9996356246125692
# 132 1.3344905758670078
# 134 1.3346011703615683
# 135 1.4143854716987931
# 131 1.4147499915756707
#
#
# tau=17.328679513998633
#
#
# Relations for 134 in embedding using distance metric
# 1 0.9999933150483458
# 133 1.3346011703615683
# 135 1.3347437328508658
# 136 1.4145411184595351
# 132 1.4148476956135727
#
#
# tau=17.328679513998633
#
#
# Relations for 135 in embedding using distance metric
# 1 0.9997781871114353
# 136 1.3343265612023054
# 134 1.3347437328508658
# 133 1.4143854716987931
# 137 1.4147542705754295
#
#
# tau=17.328679513998633
#
#
# Relations for 136 in embedding using distance metric
# 1 0.9995761434112294
# 135 1.3343265612023054
# 137 1.3345527975896005
# 138 1.4143831442709438
# 134 1.4145411184595351
#
#
# tau=17.328679513998633
#
#
# Relations for 137 in embedding using distance metric
# 1 1.000004423476311
# 136 1.3345527975896005
# 138 1.3348119950495874
# 139 1.4146557046084827
# 135 1.4147542705754295
#
#
# tau=17.328679513998633
#
#
# Relations for 138 in embedding using distance metric
# 1 0.9998353408878099
# 139 1.3344871926953565
# 137 1.3348119950495874
# 140 1.4143443272379672
# 136 1.4143831442709438
#
#
# tau=17.328679513998633
#
#
# Relations for 139 in embedding using distance metric
# 1 0.9996796211406204
# 140 1.3341891782024022
# 138 1.3344871926953565
# 137 1.4146557046084827
# 141 1.4147118792908486
#
#
# tau=17.328679513998633
#
#
# Relations for 140 in embedding using distance metric
# 1 0.9995373263779734
# 139 1.3341891782024022
# 141 1.3345701552389906
# 138 1.4143443272379672
# 142 1.4144618065111467
#
#
# tau=17.328679513998633
#
#
# Relations for 141 in embedding using distance metric
# 1 1.0000605981620263
# 140 1.3345701552389906
# 142 1.334985649005105
# 139 1.4147118792908486
# 143 1.414891126382969
#
#
# tau=17.328679513998633
#
#
# Relations for 142 in embedding using distance metric
# 1 0.9999528201305161
# 143 1.3347839190606199
# 141 1.334985649005105
# 140 1.4144618065111467
# 144 1.4147033196521517
#
#
# tau=17.328679513998633
#
#
# Relations for 143 in embedding using distance metric
# 1 0.9998588682054678
# 144 1.3346099384354708
# 142 1.3347839190606199
# 145 1.414543367386691
# 141 1.414891126382969
#
#
# tau=17.328679513998633
#
#
# Relations for 144 in embedding using distance metric
# 1 0.9997788395355637
# 145 1.3344639093837274
# 143 1.3346099384354708
# 146 1.414411480134846
# 142 1.4147033196521517
#
#
# tau=17.328679513998633
#
#
# Relations for 145 in embedding using distance metric
# 1 0.9997128391861148
# 146 1.33434605049161
# 144 1.3344639093837274
# 147 1.4143078850532662
# 143 1.414543367386691
#
#
# tau=17.328679513998633
#
#
# Relations for 146 in embedding using distance metric
# 1 0.9996609806374309
# 147 1.3342565972099605
# 145 1.33434605049161
# 148 1.4142328264607613
# 144 1.414411480134846
#
#
# tau=17.328679513998633
#
#
# Relations for 147 in embedding using distance metric
# 1 0.999623385900158
# 148 1.3341958024280218
# 146 1.3342565972099605
# 149 1.4141865664347615
# 145 1.4143078850532662
#
#
# tau=17.328679513998633
#
#
# Relations for 148 in embedding using distance metric
# 1 0.9996001858529037
# 149 1.334163937091175
# 147 1.3341958024280218
# 150 1.4141693854533457
# 146 1.4142328264607613
#
#
# tau=17.328679513998633
#
#
# Relations for 149 in embedding using distance metric
# 1 0.9995915205624761
# 150 1.3341612908657137
# 148 1.334163937091175
# 151 1.4141815830858944
# 147 1.4141865664347615
#
#
# tau=17.328679513998633
#
#
# Relations for 150 in embedding using distance metric
# 1 0.9995975396283657
# 149 1.3341612908657137
# 151 1.3341881728536908
# 148 1.4141693854533457
# 152 1.4142234787357526
#
#
# tau=17.328679513998633
#
#
# Relations for 151 in embedding using distance metric
# 1 0.9996184025531601
# 150 1.3341881728536908
# 152 1.334244912361551
# 149 1.4141815830858944
# 153 1.414295412438654
#
#
# tau=17.328679513998633
#
#
# Relations for 152 in embedding using distance metric
# 1 0.9996542791407365
# 151 1.334244912361551
# 153 1.334331859726321
# 150 1.4142234787357526
# 154 1.4143977457209198
#
#
# tau=17.328679513998633
#
#
# Relations for 153 in embedding using distance metric
# 1 0.9997053499242572
# 152 1.334331859726321
# 154 1.3344493872036025
# 151 1.414295412438654
# 155 1.4145308625219175
#
#
# tau=17.328679513998633
#
#
# Relations for 154 in embedding using distance metric
# 1 0.9997718066261828
# 153 1.3344493872036025
# 155 1.3345978899220616
# 152 1.4143977457209198
# 156 1.4146951701856838
#
#
# tau=17.328679513998633
#
#
# Relations for 155 in embedding using distance metric
# 1 0.9998538526061426
# 154 1.3345978899220616
# 156 1.3347777869095108
# 153 1.4145308625219175
# 157 1.414891100527034
#
#
# tau=17.328679513998633
#
#
# Relations for 156 in embedding using distance metric
# 1 0.9999517035783658
# 155 1.3347777869095108
# 157 1.3349895221961134
# 154 1.4146951701856838
# 158 1.4151191109781012
#
#
# tau=17.328679513998633
#
#
# Relations for 157 in embedding using distance metric
# 1 1.0000655879054123
# 156 1.3349895221961134
# 158 1.3352335660010262
# 159 1.4145611217194451
# 155 1.414891100527034
#
#
# tau=17.328679513998633
#
#
# Relations for 158 in embedding using distance metric
# 1 1.0001957473978493
# 159 1.3346918519068778
# 157 1.3352335660010262
# 160 1.4148429951126857
# 156 1.4151191109781012
#
#
# tau=17.328679513998633
#
#
# Relations for 159 in embedding using distance metric
# 1 0.9995238738276122
# 160 1.334171692236591
# 158 1.3346918519068778
# 161 1.4143395794161837
# 157 1.4145611217194451
#
#
# tau=17.328679513998633
#
#
# Relations for 160 in embedding using distance metric
# 1 0.9996755877458429
# 159 1.334171692236591
# 161 1.3344918640275032
# 162 1.4146767824611617
# 158 1.4148429951126857
#
#
# tau=17.328679513998633
#
#
# Relations for 161 in embedding using distance metric
# 1 0.9998440455889268
# 160 1.3344918640275032
# 162 1.3348458110462942
# 163 1.4141931183272043
# 159 1.4143395794161837
#
#
# tau=17.328679513998633
#
#
# Relations for 162 in embedding using distance metric
# 1 1.0000295347364303
# 163 1.3343791781664158
# 161 1.3348458110462942
# 164 1.414586230408607
# 160 1.4146767824611617
#
#
# tau=17.328679513998633
#
#
# Relations for 163 in embedding using distance metric
# 1 0.9993774127320965
# 164 1.3339346790950886
# 162 1.3343791781664158
# 165 1.4141593335480402
# 161 1.4141931183272043
#
#
# tau=17.328679513998633
#
#
# Relations for 164 in embedding using distance metric
# 1 0.9995850356901453
# 163 1.3339346790950886
# 165 1.3343675271958018
# 162 1.414586230408607
# 166 1.4146101239085052
#
#
# tau=17.328679513998633
#
#
# Relations for 165 in embedding using distance metric
# 1 0.9998102608077413
# 164 1.3343675271958018
# 166 1.3348359197670292
# 163 1.4141593335480402
# 167 1.4142021054883336
#
#
# tau=17.328679513998633
#
#
# Relations for 166 in embedding using distance metric
# 1 1.000053428237753
# 167 1.3344458436065991
# 165 1.3348359197670292
# 164 1.4146101239085052
# 168 1.414711332458215
#
#
# tau=17.328679513998633
#
#
# Relations for 167 in embedding using distance metric
# 1 0.9994201846772882
# 168 1.3340786595850713
# 166 1.3344458436065991
# 165 1.4142021054883336
# 169 1.4143627798463532
#
#
# tau=17.328679513998633
#
#
# Relations for 168 in embedding using distance metric
# 1 0.9996862442482592
# 167 1.3340786595850713
# 169 1.3346294101034961
# 170 1.414009219329708
# 166 1.414711332458215
#
#
# tau=17.328679513998633
#
#
# Relations for 169 in embedding using distance metric
# 1 0.9999709351753633
# 170 1.3342944809966142
# 168 1.3346294101034961
# 167 1.4143627798463532
# 171 1.414602078797409
#
#
# tau=17.328679513998633
#
#
# Relations for 170 in embedding using distance metric
# 1 0.9993513151223639
# 171 1.333983029429214
# 169 1.3342944809966142
# 168 1.414009219329708
# 172 1.4143100385448548
#
#
# tau=17.328679513998633
#
#
# Relations for 171 in embedding using distance metric
# 1 0.9996594836450867
# 170 1.333983029429214
# 172 1.3346187777511975
# 173 1.4140117785879514
# 169 1.414602078797409
#
#
# tau=17.328679513998633
#
#
# Relations for 172 in embedding using distance metric
# 1 0.9999870634273624
# 173 1.334339929109225
# 171 1.3346187777511975
# 170 1.4143100385448548
# 174 1.4146911047774566
#
#
# tau=17.328679513998633
#
#
# Relations for 173 in embedding using distance metric
# 1 0.9993806349874924
# 174 1.3340852470197895
# 172 1.334339929109225
# 171 1.4140117785879514
# 175 1.4144567153257908
#
#
# tau=17.328679513998633
#
#
# Relations for 174 in embedding using distance metric
# 1 0.9997323813802551
# 173 1.3340852470197895
# 175 1.334809032399538
# 176 1.4142148154098182
# 172 1.4146911047774566
#
#
# tau=17.328679513998633
#
#
# Relations for 175 in embedding using distance metric
# 1 1.0001044203537133
# 176 1.3345874251214034
# 174 1.334809032399538
# 173 1.4144567153257908
# 177 1.414983863700408
#
#
# tau=17.328679513998633
#
#
# Relations for 176 in embedding using distance metric
# 1 0.9995107740899873
# 177 1.3343907881161996
# 175 1.3345874251214034
# 178 1.4138048755111257
# 174 1.4142148154098182
#
#
# tau=17.328679513998633
#
#
# Relations for 177 in embedding using distance metric
# 1 0.9999077833367541
# 178 1.334202455495697
# 176 1.3343907881161996
# 179 1.4146242714239723
# 175 1.414983863700408
#
#
# tau=17.328679513998633
#
#
# Relations for 178 in embedding using distance metric
# 1 0.9993224414593187
# 179 1.334039500224515
# 177 1.334202455495697
# 176 1.4138048755111257
# 180 1.4144831289106938
#
#
# tau=17.328679513998633
#
#
# Relations for 179 in embedding using distance metric
# 1 0.9997448281164094
# 178 1.334039500224515
# 180 1.3349060862444904
# 181 1.4143323192678583
# 177 1.4146242714239723
#
#
# tau=17.328679513998633
#
#
# Relations for 180 in embedding using distance metric
# 1 1.0001890274713219
# 181 1.3347770893596025
# 179 1.3349060862444904
# 178 1.4144831289106938
# 182 1.4152470991313002
#
#
# tau=17.328679513998633
#
#
# Relations for 181 in embedding using distance metric
# 1 0.9996158312249874
# 182 1.3346744735601264
# 180 1.3347770893596025
# 183 1.4141086044451434
# 179 1.4143323192678583
#
#
# tau=17.328679513998633
#
#
# Relations for 182 in embedding using distance metric
# 1 1.0000864116657273
# 183 1.3345797556223327
# 181 1.3346744735601264
# 184 1.415076666111164
# 180 1.4152470991313002
#
#
# tau=17.328679513998633
#
#
# Relations for 183 in embedding using distance metric
# 1 0.9995211132827138
# 184 1.3345119384016912
# 182 1.3345797556223327
# 185 1.4139538139136156
# 181 1.4141086044451434
#
#
# tau=17.328679513998633
#
#
# Relations for 184 in embedding using distance metric
# 1 1.0000185944410371
# 185 1.3344518658079825
# 183 1.3345119384016912
# 186 1.4149762396489947
# 182 1.415076666111164
#
#
# tau=17.328679513998633
#
#
# Relations for 185 in embedding using distance metric
# 1 0.9994610406866145
# 186 1.334419256566465
# 184 1.3344518658079825
# 187 1.4138687284825378
# 183 1.4139538139136156
#
#
# tau=17.328679513998633
#
#
# Relations for 186 in embedding using distance metric
# 1 0.9999859851975711
# 187 1.3343942437291099
# 185 1.334419256566465
# 188 1.4149466892282316
# 184 1.4149762396489947
#
#
# tau=17.328679513998633
#
#
# Relations for 187 in embedding using distance metric
# 1 0.9994360278489902
# 186 1.3343942437291099
# 188 1.3343973025498659
# 189 1.4138542274462638
# 185 1.4138687284825378
#
#
# tau=17.328679513998633
#
#
# Relations for 188 in embedding using distance metric
# 1 0.9999890440185115
# 187 1.3343973025498659
# 189 1.3344078143509523
# 186 1.4149466892282316
# 190 1.414988988444502
#
#
# tau=17.328679513998633
#
#
# Relations for 189 in embedding using distance metric
# 1 0.9994465396519563
# 188 1.3344078143509523
# 190 1.3344470547464555
# 187 1.4138542274462638
# 191 1.41391129379649
#
#
# tau=17.328679513998633
#
#
# Relations for 190 in embedding using distance metric
# 1 1.0000282844163642
# 189 1.3344470547464555
# 191 1.3344936092955948
# 188 1.414988988444502
# 192 1.4151042208342897
#
#
# tau=17.328679513998633
#
#
# Relations for 191 in embedding using distance metric
# 1 0.9994930942051554
# 190 1.3344936092955948
# 192 1.3345696012898562
# 189 1.41391129379649
# 193 1.4140410200727254
#
#
# tau=17.328679513998633
#
#
# Relations for 192 in embedding using distance metric
# 1 1.0001042764151673
# 191 1.3345696012898562
# 193 1.3346527730169422
# 190 1.4151042208342897
# 194 1.4152935864117424
#
#
# tau=17.328679513998633
#
#
# Relations for 193 in embedding using distance metric
# 1 0.9995762659385109
# 192 1.3346527730169422
# 194 1.3347661466001004
# 191 1.4140410200727254
# 195 1.414244614919526
#
#
# tau=17.328679513998633
#
#
# Relations for 194 in embedding using distance metric
# 1 1.0002176500050879
# 193 1.3347661466001004
# 195 1.3348865697197931
# 196 1.4143685152567618
# 192 1.4152935864117424
#
#
# tau=17.328679513998633
#
#
# Relations for 195 in embedding using distance metric
# 1 0.9996966890667143
# 196 1.3338481249817786
# 194 1.3348865697197931
# 193 1.414244614919526
# 197 1.4145234104294788
#
#
# tau=17.328679513998633
#
#
# Relations for 196 in embedding using distance metric
# 1 0.9991792052758657
# 195 1.3338481249817786
# 197 1.3340064973720016
# 198 1.4134953046979184
# 194 1.4143685152567618
#
#
# tau=17.328679513998633
#
#
# Relations for 197 in embedding using distance metric
# 1 0.9998550613958758
# 196 1.3340064973720016
# 198 1.3341717315512907
# 195 1.4145234104294788
# 199 1.414878870362962
#
#
# tau=17.328679513998633
#
#
# Relations for 198 in embedding using distance metric
# 1 0.9993444394664367
# 197 1.3341717315512907
# 199 1.3343688190945022
# 196 1.4134953046979184
# 200 1.4138643678406604
#
#
# tau=17.328679513998633
#
#
# Relations for 199 in embedding using distance metric
# 1 1.0000521489508798
# 198 1.3343688190945022
# 200 1.334572648057904
# 197 1.414878870362962
# 201 1.41531259934985
#
#
# tau=17.328679513998633
#
#
# Relations for 200 in embedding using distance metric
# 1 0.999548268443423
# 199 1.334572648057904
# 201 1.3348092895015227
# 198 1.4138643678406604
# 202 1.414311462958326
#
#
# tau=17.328679513998633
#
#
# Relations for 201 in embedding using distance metric
# 1 1.0002887904086024
# 200 1.3348092895015227
# 202 1.3350525556557233
# 203 1.41455799880577
# 199 1.41531259934985
#
#
# tau=17.328679513998633
#
#
# Relations for 202 in embedding using distance metric
# 1 0.9997915345384946
# 203 1.334061313668133
# 201 1.3350525556557233
# 200 1.414311462958326
# 204 1.4148383530303605
#
#
# tau=17.328679513998633
#
#
# Relations for 203 in embedding using distance metric
# 1 0.9992975484372263
# 202 1.334061313668133
# 204 1.3343449375858922
# 205 1.4138568369305993
# 201 1.41455799880577
#
#
# tau=17.328679513998633
#
#
# Relations for 204 in embedding using distance metric
# 1 1.0000751584732281
# 203 1.3343449375858922
# 205 1.334635017698405
# 206 1.4141501043728255
# 202 1.4148383530303605
#
#
# tau=17.328679513998633
#
#
# Relations for 205 in embedding using distance metric
# 1 0.9995876285685443
# 206 1.333663145123205
# 204 1.334635017698405
# 203 1.4138568369305993
# 207 1.414478251595079
#
#
# tau=17.328679513998633
#
#
# Relations for 206 in embedding using distance metric
# 1 0.9991032859171471
# 205 1.333663145123205
# 207 1.333994479675094
# 208 1.4135158614839212
# 204 1.4141501043728255
#
#
# tau=17.328679513998633
#
#
# Relations for 207 in embedding using distance metric
# 1 0.9999189630633387
# 206 1.333994479675094
# 208 1.3343321093614695
# 205 1.414478251595079
# 209 1.4151832743136146
#
#
# tau=17.328679513998633
#
#
# Relations for 208 in embedding using distance metric
# 1 0.9994409156252642
# 207 1.3343321093614695
# 209 1.33470579752802
# 206 1.4135158614839212
# 210 1.4142333710295778
#
#
# tau=17.328679513998633
#
#
# Relations for 209 in embedding using distance metric
# 1 1.0002926512521895
# 208 1.33470579752802
# 210 1.335085677387203
# 211 1.4146163088885322
# 207 1.4151832743136146
#
#
# tau=17.328679513998633
#
#
# Relations for 210 in embedding using distance metric
# 1 0.9998207954283721
# 211 1.3341450237956531
# 209 1.335085677387203
# 208 1.4142333710295778
# 212 1.41503658183164
#
#
# tau=17.328679513998633
#
#
# Relations for 211 in embedding using distance metric
# 1 0.9993519976851207
# 210 1.3341450237956531
# 212 1.334568354738418
# 213 1.4141050283720351
# 209 1.4146163088885322
#
#
# tau=17.328679513998633
#
#
# Relations for 212 in embedding using distance metric
# 1 1.000244126396432
# 211 1.334568354738418
# 213 1.3349977278135408
# 214 1.4145373862898387
# 210 1.41503658183164
#
#
# tau=17.328679513998633
#
#
# Relations for 213 in embedding using distance metric
# 1 0.9997813707052136
# 214 1.3340752013290456
# 212 1.3349977278135408
# 211 1.4141050283720351
# 215 1.4150084376874832
#
#
# tau=17.328679513998633
#
#
# Relations for 214 in embedding using distance metric
# 1 0.9993215999394395
# 213 1.3340752013290456
# 215 1.3345492375692471
# 216 1.4140947950092746
# 212 1.4145373862898387
#
#
# tau=17.328679513998633
#
#
# Relations for 215 in embedding using distance metric
# 1 1.000255406973744
# 214 1.3345492375692471
# 216 1.3350291727732333
# 217 1.4145776450057
# 213 1.4150084376874832
#
#
# tau=17.328679513998633
#
#
# Relations for 216 in embedding using distance metric
# 1 0.9998015350894769
# 217 1.3341243438513155
# 215 1.3350291727732333
# 214 1.4140947950092746
# 218 1.4151006645760584
#
#
# tau=17.328679513998633
#
#
# Relations for 217 in embedding using distance metric
# 1 0.9993505780823859
# 216 1.3341243438513155
# 218 1.3346502782139702
# 219 1.414204512284156
# 215 1.4145776450057
#
#
# tau=17.328679513998633
#
#
# Relations for 218 in embedding using distance metric
# 1 1.0003274694835407
# 217 1.3346502782139702
# 219 1.3351819744143965
# 220 1.4147390561651148
# 216 1.4151006645760584
#
#
# tau=17.328679513998633
#
#
# Relations for 219 in embedding using distance metric
# 1 0.9998822742299687
# 220 1.3342944316408503
# 218 1.3351819744143965
# 221 1.413854339326761
# 217 1.414204512284156
#
#
# tau=17.328679513998633
#
#
# Relations for 220 in embedding using distance metric
# 1 0.999439926743651
# 221 1.3334125624830717
# 219 1.3342944316408503
# 222 1.414436309703362
# 218 1.4147390561651148
#
#
# tau=17.328679513998633
#
#
# Relations for 221 in embedding using distance metric
# 1 0.9990004051064522
# 220 1.3334125624830717
# 222 1.333997358794912
# 223 1.4135628543241043
# 219 1.413854339326761
#
#
# tau=17.328679513998633
#
#
# Relations for 222 in embedding using distance metric
# 1 1.0000247230037864
# 221 1.333997358794912
# 223 1.334587742950072
# 224 1.4141560009779433
# 220 1.414436309703362
#
#
# tau=17.328679513998633
#
#
# Relations for 223 in embedding using distance metric
# 1 0.9995907892986676
# 224 1.3337226379128453
# 222 1.334587742950072
# 221 1.4135628543241043
# 225 1.4147926260921921
#
#
# tau=17.328679513998633
#
#
# Relations for 224 in embedding using distance metric
# 1 0.999159618003966
# 223 1.3337226379128453
# 225 1.3343620255256134
# 226 1.4139357471419791
# 222 1.4141560009779433
#
#
# tau=17.328679513998633
#
#
# Relations for 225 in embedding using distance metric
# 1 1.0002301768608965
# 224 1.3343620255256134
# 226 1.3350068767269017
# 227 1.4145832999931003
# 223 1.4147926260921921
#
#
# tau=17.328679513998633
#
#
# Relations for 226 in embedding using distance metric
# 1 0.999804469154666
# 227 1.3341581630150734
# 225 1.3350068767269017
# 228 1.4137372681996132
# 224 1.4139357471419791
#
#
# tau=17.328679513998633
#
#
# Relations for 227 in embedding using distance metric
# 1 0.9993814631896469
# 228 1.333314832871444
# 226 1.3341581630150734
# 229 1.4144355664234007
# 225 1.4145832999931003
#
#
# tau=17.328679513998633
#
#
# Relations for 228 in embedding using distance metric
# 1 0.998961139052238
# 227 1.333314832871444
# 229 1.3340158130135968
# 230 1.413600223907903
# 226 1.4137372681996132
#
#
# tau=17.328679513998633
#
#
# Relations for 229 in embedding using distance metric
# 1 1.0000824432824065
# 228 1.3340158130135968
# 230 1.3347220988655264
# 231 1.4143091340731335
# 227 1.4144355664234007
#
#
# tau=17.328679513998633
#
#
# Relations for 230 in embedding using distance metric
# 1 0.9996674248547421
# 231 1.333894686373133
# 229 1.3347220988655264
# 232 1.4134843272064799
# 228 1.413600223907903
#
#
# tau=17.328679513998633
#
#
# Relations for 231 in embedding using distance metric
# 1 0.9992550308344291
# 232 1.3330725038197904
# 230 1.333894686373133
# 233 1.4142458664088164
# 229 1.4143091340731335
#
#
# tau=17.328679513998633
#
#
# Relations for 232 in embedding using distance metric
# 1 0.9988452423464511
# 231 1.3330725038197904
# 233 1.3338366486478794
# 234 1.413431445666191
# 230 1.4134843272064799
#
#
# tau=17.328679513998633
#
#
# Relations for 233 in embedding using distance metric
# 1 1.0000191756143173
# 232 1.3338366486478794
# 234 1.3346059496609344
# 235 1.4142032977255938
# 231 1.4142458664088164
#
#
# tau=17.328679513998633
#
#
# Relations for 234 in embedding using distance metric
# 1 0.9996145433112782
# 235 1.3337992361496358
# 233 1.3346059496609344
# 236 1.413399117547496
# 232 1.413431445666191
#
#
# tau=17.328679513998633
#
#
# Relations for 235 in embedding using distance metric
# 1 0.999212462151321
# 236 1.3329976070178842
# 234 1.3337992361496358
# 233 1.4142032977255938
# 237 1.4142256836492775
#
#
# tau=17.328679513998633
#
#
# Relations for 236 in embedding using distance metric
# 1 0.9988129142284776
# 235 1.3329976070178842
# 237 1.3338267064528675
# 234 1.413399117547496
# 238 1.413431602308422
#
#
# tau=17.328679513998633
#
#
# Relations for 237 in embedding using distance metric
# 1 1.0000415615393372
# 236 1.3338267064528675
# 238 1.3346608203455403
# 235 1.4142256836492775
# 239 1.414268197780842
#
#
# tau=17.328679513998633
#
#
# Relations for 238 in embedding using distance metric
# 1 0.9996470280741564
# 239 1.3338742350421176
# 237 1.3346608203455403
# 236 1.413431602308422
# 240 1.4134840772546855
#
#
# tau=17.328679513998633
#
#
# Relations for 239 in embedding using distance metric
# 1 0.9992549762881463
# 240 1.3330925960956923
# 238 1.3338742350421176
# 237 1.414268197780842
# 241 1.4143776935293269
#
#
# tau=17.328679513998633
#
#
# Relations for 240 in embedding using distance metric
# 1 0.9988653891806274
# 239 1.3330925960956923
# 241 1.3339886771475957
# 238 1.4134840772546855
# 242 1.4136033993779318
#
#
# tau=17.328679513998633
#
#
# Relations for 241 in embedding using distance metric
# 1 1.0001510572943444
# 240 1.3339886771475957
# 242 1.3348896382172426
# 239 1.4143776935293269
# 243 1.4145067761140746
#
#
# tau=17.328679513998633
#
#
# Relations for 242 in embedding using distance metric
# 1 0.9997663502045587
# 243 1.334122639750079
# 241 1.3348896382172426
# 240 1.4136033993779318
# 244 1.4137421773630552
#
#
# tau=17.328679513998633
#
#
# Relations for 243 in embedding using distance metric
# 1 0.9993840588833841
# 244 1.3333604566655255
# 242 1.334122639750079
# 241 1.4145067761140746
# 245 1.414705127124589
#
#
# tau=17.328679513998633
#
#
# Relations for 244 in embedding using distance metric
# 1 0.9990041671768806
# 243 1.3333604566655255
# 245 1.3343258061431837
# 242 1.4137421773630552
# 246 1.4139500961528682
#
#
# tau=17.328679513998633
#
#
# Relations for 245 in embedding using distance metric
# 1 1.000349408316639
# 244 1.3343258061431837
# 246 1.3352959080175202
# 243 1.414705127124589
# 247 1.4149225511068493
#
#
# tau=17.328679513998633
#
#
# Relations for 246 in embedding using distance metric
# 1 0.999974269006804
# 247 1.3345479825220905
# 245 1.3352959080175202
# 244 1.4139500961528682
# 248 1.4141769635390318
#
#
# tau=17.328679513998633
#
#
# Relations for 247 in embedding using distance metric
# 1 0.9996014827764773
# 248 1.3338047480338924
# 246 1.3345479825220905
# 249 1.413436052018308
# 245 1.4149225511068493
#
#
# tau=17.328679513998633
#
#
# Relations for 248 in embedding using distance metric
# 1 0.9992310345794871
# 249 1.3330661744409742
# 247 1.3338047480338924
# 246 1.4141769635390318
# 250 1.4144755513956462
#
#
# tau=17.328679513998633
#
#
# Relations for 249 in embedding using distance metric
# 1 0.9988629092451227
# 248 1.3330661744409742
# 250 1.3341079967857559
# 247 1.413436052018308
# 251 1.4137439025765908
#
#
# tau=17.328679513998633
#
#
# Relations for 250 in embedding using distance metric
# 1 1.0002728568811916
# 249 1.3341079967857559
# 251 1.335154420936908
# 248 1.4144755513956462
# 252 1.414792605935112
#
#
# tau=17.328679513998633
#
#
# Relations for 251 in embedding using distance metric
# 1 0.9999093333532029
# 252 1.3344296531315523
# 250 1.335154420936908
# 249 1.4137439025765908
# 253 1.4140701031137286
#
#
# tau=17.328679513998633
#
#
# Relations for 252 in embedding using distance metric
# 1 0.9995480890324379
# 253 1.3337094295174947
# 251 1.3344296531315523
# 254 1.4133521304375856
# 250 1.414792605935112
#
#
# tau=17.328679513998633
#
#
# Relations for 253 in embedding using distance metric
# 1 0.9991891098047526
# 254 1.3329937218255135
# 252 1.3337094295174947
# 251 1.4140701031137286
# 255 1.4144708073962862
#
#
# tau=17.328679513998633
#
#
# Relations for 254 in embedding using distance metric
# 1 0.9988323814067545
# 253 1.3329937218255135
# 255 1.3341146497220844
# 252 1.4133521304375856
# ...
# 915 1.3347335582371396
# 918 1.4149033768454613
# 914 1.4149411746339513
#
#
# tau=17.328679513998633
#
#
# Relations for 917 in embedding using distance metric
# 1 0.999822343746408
# 916 1.3347214901062727
# 918 1.3347993756407257
# 915 1.41462841562694
# 919 1.4147932039948103
#
#
# tau=17.328679513998633
#
#
# Relations for 918 in embedding using distance metric
# 1 1.0000048011849199
# 917 1.3347993756407257
# 919 1.3349762321394443
# 916 1.4149033768454613
# 920 1.415020761895457
#
#
# tau=17.328679513998633
#
#
# Relations for 919 in embedding using distance metric
# 1 0.9999992002413985
# 918 1.3349762321394443
# 920 1.3350157316549687
# 917 1.4147932039948103
# 921 1.4148917233515323
#
#
# tau=17.328679513998633
#
#
# Relations for 920 in embedding using distance metric
# 1 1.0000443007028053
# 921 1.33493739451296
# 919 1.3350157316549687
# 922 1.4148725461125822
# 918 1.415020761895457
#
#
# tau=17.328679513998633
#
#
# Relations for 921 in embedding using distance metric
# 1 0.9999208631077007
# 922 1.3347496792145808
# 920 1.33493739451296
# 923 1.414742420656354
# 919 1.4148917233515323
#
#
# tau=17.328679513998633
#
#
# Relations for 922 in embedding using distance metric
# 1 0.9998565854058703
# 923 1.33467871366143
# 921 1.3347496792145808
# 924 1.414727645821372
# 920 1.4148725461125822
#
#
# tau=17.328679513998633
#
#
# Relations for 923 in embedding using distance metric
# 1 0.9998498975496626
# 922 1.33467871366143
# 924 1.33472152866862
# 921 1.414742420656354
# 925 1.4148254096254917
#
#
# tau=17.328679513998633
#
#
# Relations for 924 in embedding using distance metric
# 1 0.9998994004149958
# 923 1.33472152866862
# 925 1.3348754831908969
# 922 1.414727645821372
# 926 1.4148411768469051
#
#
# tau=17.328679513998633
#
#
# Relations for 925 in embedding using distance metric
# 1 1.000003852068795
# 924 1.3348754831908969
# 926 1.3349461992092246
# 923 1.4148254096254917
# 927 1.4149741348827272
#
#
# tau=17.328679513998633
#
#
# Relations for 926 in embedding using distance metric
# 1 0.9999701164255089
# 927 1.334940969944164
# 925 1.3349461992092246
# 924 1.4148411768469051
# 928 1.4148478871300574
#
#
# tau=17.328679513998633
#
#
# Relations for 927 in embedding using distance metric
# 1 0.9999986228034202
# 928 1.3348769642089846
# 926 1.334940969944164
# 929 1.4148527740372776
# 925 1.4149741348827272
#
#
# tau=17.328679513998633
#
#
# Relations for 928 in embedding using distance metric
# 1 0.9999061106973353
# 929 1.3347608326286167
# 927 1.3348769642089846
# 930 1.414803655310386
# 926 1.4148478871300574
#
#
# tau=17.328679513998633
#
#
# Relations for 929 in embedding using distance metric
# 1 0.9998824912266392
# 928 1.3347608326286167
# 930 1.3347806065441243
# 927 1.4148527740372776
# 931 1.4148887887488526
#
#
# tau=17.328679513998633
#
#
# Relations for 930 in embedding using distance metric
# 1 0.9999258846134469
# 929 1.3347806065441243
# 931 1.334932752836069
# 932 1.4147797335255803
# 928 1.414803655310386
#
#
# tau=17.328679513998633
#
#
# Relations for 931 in embedding using distance metric
# 1 1.000034637517144
# 932 1.3348890571357555
# 930 1.334932752836069
# 929 1.4148887887488526
# 933 1.4149739634935614
#
#
# tau=17.328679513998633
#
#
# Relations for 932 in embedding using distance metric
# 1 0.9998821889099467
# 933 1.3348220855885073
# 931 1.3348890571357555
# 930 1.4147797335255803
# 934 1.414822910728918
#
#
# tau=17.328679513998633
#
#
# Relations for 933 in embedding using distance metric
# 1 0.9999676659658933
# 932 1.3348220855885073
# 934 1.334908958492154
# 935 1.4148372759449825
# 931 1.4149739634935614
#
#
# tau=17.328679513998633
#
#
# Relations for 934 in embedding using distance metric
# 1 0.9999690618091134
# 935 1.3348392424908433
# 933 1.334908958492154
# 932 1.414822910728918
# 936 1.4148502061528299
#
#
# tau=17.328679513998633
#
#
# Relations for 935 in embedding using distance metric
# 1 0.9998979499692658
# 936 1.3347796650111015
# 934 1.3348392424908433
# 933 1.4148372759449825
# 937 1.4148708947759683
#
#
# tau=17.328679513998633
#
#
# Relations for 936 in embedding using distance metric
# 1 0.9999094843343989
# 935 1.3347796650111015
# 937 1.3348829998433966
# 938 1.4147815062760647
# 934 1.4148502061528299
#
#
# tau=17.328679513998633
#
#
# Relations for 937 in embedding using distance metric
# 1 1.0000012847988853
# 938 1.3348738774463804
# 936 1.3348829998433966
# 935 1.4148708947759683
# 939 1.414995869400764
#
#
# tau=17.328679513998633
#
#
# Relations for 938 in embedding using distance metric
# 1 0.9999003619363145
# 937 1.3348738774463804
# 939 1.3348955172388641
# 936 1.4147815062760647
# 940 1.4148450912967114
#
#
# tau=17.328679513998633
#
#
# Relations for 939 in embedding using distance metric
# 1 1.0000229245926635
# 938 1.3348955172388641
# 940 1.3349682246565209
# 937 1.414995869400764
# 941 1.4150129986482567
#
#
# tau=17.328679513998633
#
#
# Relations for 940 in embedding using distance metric
# 1 0.9999730693502511
# 941 1.3349637141115236
# 939 1.3349682246565209
# 938 1.4148450912967114
# 942 1.4148633596773896
#
#
# tau=17.328679513998633
#
#
# Relations for 941 in embedding using distance metric
# 1 1.0000184140473989
# 942 1.3349092750745468
# 940 1.3349637141115236
# 943 1.4149139799503299
# 939 1.4150129986482567
#
#
# tau=17.328679513998633
#
#
# Relations for 942 in embedding using distance metric
# 1 0.9999186303170879
# 943 1.3348147669216273
# 941 1.3349092750745468
# 944 1.4148104191430593
# 940 1.4148633596773896
#
#
# tau=17.328679513998633
#
#
# Relations for 943 in embedding using distance metric
# 1 0.9999239058956612
# 942 1.3348147669216273
# 944 1.3348162654242828
# 941 1.4149139799503299
# 945 1.4149177686976553
#
#
# tau=17.328679513998633
#
#
# Relations for 944 in embedding using distance metric
# 1 0.9999201288193587
# 943 1.3348162654242828
# 945 1.334914562324526
# 942 1.4148104191430593
# 946 1.4149122957976286
#
#
# tau=17.328679513998633
#
#
# Relations for 945 in embedding using distance metric
# 1 1.0000222027949508
# 944 1.334914562324526
# 946 1.3350149404764278
# 943 1.4149177686976553
# 947 1.414927647273092
#
#
# tau=17.328679513998633
#
#
# Relations for 946 in embedding using distance metric
# 1 1.0000205069706645
# 947 1.3349265221516184
# 945 1.3350149404764278
# 944 1.4149122957976286
# 948 1.4149632238218108
#
#
# tau=17.328679513998633
#
#
# Relations for 947 in embedding using distance metric
# 1 0.9999337844707697
# 948 1.3348770720238912
# 946 1.3349265221516184
# 949 1.4148493828541289
# 945 1.414927647273092
#
#
# tau=17.328679513998633
#
#
# Relations for 948 in embedding using distance metric
# 1 0.9999710568456804
# 947 1.3348770720238912
# 949 1.3348872259297508
# 950 1.4149002043467116
# 946 1.4149632238218108
#
#
# tau=17.328679513998633
#
#
# Relations for 949 in embedding using distance metric
# 1 0.9999439383768015
# 950 1.3348736565823847
# 948 1.3348872259297508
# 947 1.4148493828541289
# 951 1.4149327868260873
#
#
# tau=17.328679513998633
#
#
# Relations for 950 in embedding using distance metric
# 1 0.9999574874970769
# 949 1.3348736565823847
# 951 1.3349469066484734
# 952 1.4148941308617466
# 948 1.4149002043467116
#
#
# tau=17.328679513998633
#
#
# Relations for 951 in embedding using distance metric
# 1 1.0000171884417886
# 950 1.3349469066484734
# 952 1.3349544025108757
# 949 1.4149327868260873
# 953 1.414970766573395
#
#
# tau=17.328679513998633
#
#
# Relations for 952 in embedding using distance metric
# 1 0.9999649833595168
# 953 1.334919132192089
# 951 1.3349544025108757
# 950 1.4148941308617466
# 954 1.4149334911698512
#
#
# tau=17.328679513998633
#
#
# Relations for 953 in embedding using distance metric
# 1 0.9999819181208927
# 952 1.334919132192089
# 954 1.3349509966377848
# 955 1.414904586488577
# 951 1.414970766573395
#
#
# tau=17.328679513998633
#
#
# Relations for 954 in embedding using distance metric
# 1 0.9999968478022584
# 955 1.334920086871765
# 953 1.3349509966377848
# 952 1.4149334911698512
# 956 1.4149716009578852
#
#
# tau=17.328679513998633
#
#
# Relations for 955 in embedding using distance metric
# 1 0.9999510083572989
# 954 1.334920086871765
# 956 1.3349263322140952
# 957 1.4148810910672451
# 953 1.414904586488577
#
#
# tau=17.328679513998633
#
#
# Relations for 956 in embedding using distance metric
# 1 1.0000030931449637
# 955 1.3349263322140952
# 957 1.3349337465587894
# 958 1.4149452283068074
# 954 1.4149716009578852
#
#
# tau=17.328679513998633
#
#
# Relations for 957 in embedding using distance metric
# 1 0.999958422702066
# 958 1.3349011285653827
# 956 1.3349337465587894
# 955 1.4148810910672451
# 959 1.4149189281701406
#
#
# tau=17.328679513998633
#
#
# Relations for 958 in embedding using distance metric
# 1 0.9999704751533354
# 957 1.3349011285653827
# 959 1.33493155132358
# 960 1.414915838906881
# 956 1.4149452283068074
#
#
# tau=17.328679513998633
#
#
# Relations for 959 in embedding using distance metric
# 1 0.9999888454581755
# 958 1.33493155132358
# 960 1.3349347799170632
# 957 1.4149189281701406
# 961 1.4149635485825418
#
#
# tau=17.328679513998633
#
#
# Relations for 960 in embedding using distance metric
# 1 0.999973703746668
# 959 1.3349347799170632
# 961 1.3349489775712629
# 958 1.414915838906881
# 962 1.4149339221784487
#
#
# tau=17.328679513998633
#
#
# Relations for 961 in embedding using distance metric
# 1 1.0000030431132232
# 960 1.3349489775712629
# 962 1.3349638322493438
# 959 1.4149635485825418
# 963 1.4149823884720056
#
#
# tau=17.328679513998633
#
#
# Relations for 962 in embedding using distance metric
# 1 0.9999885584222532
# 961 1.3349638322493438
# 963 1.3349684744846049
# 960 1.4149339221784487
# 964 1.4149475772882802
#
#
# tau=17.328679513998633
#
#
# Relations for 963 in embedding using distance metric
# 1 1.000007685348763
# 964 1.3349672749163555
# 962 1.3349684744846049
# 961 1.4149823884720056
# 965 1.4149828082188927
#
#
# tau=17.328679513998633
#
#
# Relations for 964 in embedding using distance metric
# 1 0.9999873588566746
# 965 1.3349630524279794
# 963 1.3349672749163555
# 962 1.4149475772882802
# 966 1.414955385305278
#
#
# tau=17.328679513998633
#
#
# Relations for 965 in embedding using distance metric
# 1 1.0000034628601349
# 964 1.3349630524279794
# 966 1.3349720600132267
# 967 1.4149758270333948
# 963 1.4149828082188927
#
#
# tau=17.328679513998633
#
#
# Relations for 966 in embedding using distance metric
# 1 0.9999963664397166
# 967 1.3349693013161053
# 965 1.3349720600132267
# 968 1.4149433859674552
# 964 1.414955385305278
#
#
# tau=17.328679513998633
#
#
# Relations for 967 in embedding using distance metric
# 1 1.0000007041628487
# 968 1.334948294393037
# 966 1.3349693013161053
# 969 1.4149689641522754
# 965 1.4149758270333948
#
#
# tau=17.328679513998633
#
#
# Relations for 968 in embedding using distance metric
# 1 0.9999753595175618
# 969 1.3349441902090395
# 967 1.334948294393037
# 966 1.4149433859674552
# 970 1.4149472627071933
#
#
# tau=17.328679513998633
#
#
# Relations for 969 in embedding using distance metric
# 1 0.999996599978606
# 968 1.3349441902090395
# 970 1.3349690738718454
# 967 1.4149689641522754
# 971 1.414971891247779
#
#
# tau=17.328679513998633
#
#
# Relations for 970 in embedding using distance metric
# 1 1.0000002431796864
# 969 1.3349690738718454
# 971 1.3349761051513467
# 968 1.4149472627071933
# 972 1.4149715512231194
#
#
# tau=17.328679513998633
#
#
# Relations for 971 in embedding using distance metric
# 1 1.0000036312585274
# 972 1.3349755100044636
# 970 1.3349761051513467
# 973 1.4149669973128396
# 969 1.414971891247779
#
#
# tau=17.328679513998633
#
#
# Relations for 972 in embedding using distance metric
# 1 0.9999996480327669
# 973 1.3349635847900223
# 971 1.3349755100044636
# 974 1.414963637013801
# 970 1.4149715512231194
#
#
# tau=17.328679513998633
#
#
# Relations for 973 in embedding using distance metric
# 1 0.9999917060449205
# 974 1.33495626572759
# 972 1.3349635847900223
# 975 1.4149628584546698
# 971 1.4149669973128396
#
#
# tau=17.328679513998633
#
#
# Relations for 974 in embedding using distance metric
# 1 0.9999923289713303
# 973 1.33495626572759
# 975 1.3349640520838608
# 972 1.414963637013801
# 976 1.41496789751842
#
#
# tau=17.328679513998633
#
#
# Relations for 975 in embedding using distance metric
# 1 0.9999994924001107
# 974 1.3349640520838608
# 976 1.3349756316509116
# 973 1.4149628584546698
# 977 1.414966401642798
#
#
# tau=17.328679513998633
#
#
# Relations for 976 in embedding using distance metric
# 1 1.0000039085376398
# 977 1.3349713884827692
# 975 1.3349756316509116
# 974 1.41496789751842
# 978 1.4149773522788145
#
#
# tau=17.328679513998633
#
#
# Relations for 977 in embedding using distance metric
# 1 0.999995249232837
# 978 1.334969263676111
# 976 1.3349713884827692
# 975 1.414966401642798
# 979 1.4149675622571136
#
#
# tau=17.328679513998633
#
#
# Relations for 978 in embedding using distance metric
# 1 1.0000017837308546
# 977 1.334969263676111
# 979 1.3349746674585692
# 980 1.4149746300775925
# 976 1.4149773522788145
#
#
# tau=17.328679513998633
#
#
# Relations for 979 in embedding using distance metric
# 1 1.0000006530144954
# 980 1.3349740700640051
# 978 1.3349746674585692
# 977 1.4149675622571136
# 981 1.4149729539524365
#
#
# tau=17.328679513998633
#
#
# Relations for 980 in embedding using distance metric
# 1 1.0000011863362552
# 981 1.3349740579768699
# 979 1.3349740700640051
# 982 1.4149711143648878
# 978 1.4149746300775925
#
#
# tau=17.328679513998633
#
#
# Relations for 981 in embedding using distance metric
# 1 1.0000006409273587
# 982 1.3349711396587292
# 980 1.3349740579768699
# 983 1.4149681851791192
# 979 1.4149729539524365
#
#
# tau=17.328679513998633
#
#
# Relations for 982 in embedding using distance metric
# 1 0.9999982680179403
# 983 1.3349663829725482
# 981 1.3349711396587292
# 984 1.4149630968043938
# 980 1.4149711143648878
#
#
# tau=17.328679513998633
#
#
# Relations for 983 in embedding using distance metric
# 1 0.9999958842415074
# 984 1.3349612837301963
# 982 1.3349663829725482
# 985 1.4149675020429346
# 981 1.4149681851791192
#
#
# tau=17.328679513998633
#
#
# Relations for 984 in embedding using distance metric
# 1 0.9999931687758269
# 983 1.3349612837301963
# 985 1.334965357280192
# 982 1.4149630968043938
# 986 1.414964259184994
#
#
# tau=17.328679513998633
#
#
# Relations for 985 in embedding using distance metric
# 1 0.9999999577911333
# 984 1.334965357280192
# 986 1.3349716189031442
# 983 1.4149675020429346
# 987 1.4149697967703496
#
#
# tau=17.328679513998633
#
#
# Relations for 986 in embedding using distance metric
# 1 0.99999943039861
# 987 1.3349698400805632
# 985 1.3349716189031442
# 984 1.414964259184994
# 988 1.4149697535070482
#
#
# tau=17.328679513998633
#
#
# Relations for 987 in embedding using distance metric
# 1 0.999998178968805
# 988 1.3349690727796644
# 986 1.3349698400805632
# 989 1.4149672280613976
# 985 1.4149697967703496
#
#
# tau=17.328679513998633
#
#
# Relations for 988 in embedding using distance metric
# 1 0.9999986630979711
# 989 1.3349682828932938
# 987 1.3349690727796644
# 990 1.4149678885390933
# 986 1.4149697535070482
#
#
# tau=17.328679513998633
#
#
# Relations for 989 in embedding using distance metric
# 1 0.999997389082285
# 990 1.3349671852262377
# 988 1.3349682828932938
# 987 1.4149672280613976
# 991 1.4149672786848109
#
#
# tau=17.328679513998633
#
#
# Relations for 990 in embedding using distance metric
# 1 0.9999975654307559
# 989 1.3349671852262377
# 991 1.3349680257360217
# 988 1.4149678885390933
# 992 1.4149692132480385
#
#
# tau=17.328679513998633
#
#
# Relations for 991 in embedding using distance metric
# 1 0.9999982295920343
# 990 1.3349680257360217
# 992 1.3349704481120233
# 989 1.4149672786848109
# 993 1.4149693061720172
#
#
# tau=17.328679513998633
#
#
# Relations for 992 in embedding using distance metric
# 1 0.9999999878066895
# 991 1.3349704481120233
# 993 1.3349716350894447
# 990 1.4149692132480385
# 994 1.4149715870169919
#
#
# tau=17.328679513998633
#
#
# Relations for 993 in embedding using distance metric
# 1 0.9999994165694591
# 994 1.3349715864823968
# 992 1.3349716350894447
# 991 1.4149693061720172
# 995 1.4149704211045433
#
#
# tau=17.328679513998633
#
#
# Relations for 994 in embedding using distance metric
# 1 0.9999999391996383
# 995 1.3349715144375007
# 993 1.3349715864823968
# 996 1.4149715855692004
# 992 1.4149715870169919
#
#
# tau=17.328679513998633
#
#
# Relations for 995 in embedding using distance metric
# 1 0.999999344524508
# 994 1.3349715144375007
# 996 1.3349715615967575
# 993 1.4149704211045433
# 997 1.4149709432704947
#
#
# tau=17.328679513998633
#
#
# Relations for 996 in embedding using distance metric
# 1 0.999999986358898
# 995 1.3349715615967575
# 997 1.3349721558076049
# 994 1.4149715855692004
# 998 1.4149716326337285
#
#
# tau=17.328679513998633
#
#
# Relations for 997 in embedding using distance metric
# 1 0.9999999387353377
# 998 1.3349721557128762
# 996 1.3349721558076049
# 995 1.4149709432704947
# 999 1.414971584988843
#
#
# tau=17.328679513998633
#
#
# Relations for 998 in embedding using distance metric
# 1 0.9999999862641693
# 997 1.3349721557128762
# 999 1.3349722032203768
# 996 1.4149716326337285
# 0 1.4149716462748296
#
#
# tau=17.328679513998633
#
#
# Relations for 999 in embedding using distance metric
# 1 0.9999999862428434
# 998 1.3349722032203768
# 0 1.3349722169562068
# 997 1.414971584988843
# 2 1.4149716324963437

# %%
for j in range(2, 10000):
    bm = build('data/emb/10000r2.emb', 2, j)
    assert(bm[0] == 1)
# Out:
# tau=17.328679513998633
#
#
# Relations for 2 in embedding using distance metric
# 1 1.0000000002386356
# 0 1.0691142415094506
# 3 1.0691142417035457
# 4 1.149114231125324
# 9999 1.1491142352725907
#
#
# tau=17.328679513998633
#
#
# Relations for 3 in embedding using distance metric
# 1 1.0000000001940954
# 4 1.0691142375562792
# 2 1.0691142417035457
# 5 1.1491142313004303
# 0 1.1491142349894152
#
#
# tau=17.328679513998633
#
#
# Relations for 4 in embedding using distance metric
# 1 0.9999999960913688
# 5 1.0691142336731991
# 3 1.0691142375562792
# 2 1.149114231125324
# 6 1.1491142329411144
#
#
# tau=17.328679513998633
#
#
# Relations for 5 in embedding using distance metric
# 1 0.9999999963110154
# 4 1.0691142336731991
# 6 1.0691142396362563
# 7 1.1491142241664514
# 3 1.1491142313004303
#
#
# tau=17.328679513998633
#
#
# Relations for 6 in embedding using distance metric
# 1 1.000000002054426
# 7 1.0691142363853572
# 5 1.0691142396362563
# 8 1.1491142279076445
# 4 1.1491142329411144
#
#
# tau=17.328679513998633
#
#
# Relations for 7 in embedding using distance metric
# 1 0.9999999930601166
# 8 1.0691142253888302
# 6 1.0691142363853572
# 9 1.1491142128706375
# 5 1.1491142241664514
#
#
# tau=17.328679513998633
#
#
# Relations for 8 in embedding using distance metric
# 1 0.9999999910578993
# 9 1.0691142173439159
# 7 1.0691142253888302
# 6 1.1491142279076445
# 10 1.1491142306949451
#
#
# tau=17.328679513998633
#
#
# Relations for 9 in embedding using distance metric
# 1 0.9999999850152022
# 8 1.0691142173439159
# 10 1.0691142311277437
# 7 1.1491142128706375
# 11 1.1491142219275996
#
#
# tau=17.328679513998633
#
#
# Relations for 10 in embedding using distance metric
# 1 1.0000000048417268
# 9 1.0691142311277437
# 11 1.0691142482296196
# 12 1.1491142239558774
# 8 1.1491142306949451
#
#
# tau=17.328679513998633
#
#
# Relations for 11 in embedding using distance metric
# 1 1.0000000021170783
# 12 1.0691142277067245
# 10 1.0691142482296196
# 9 1.1491142219275996
# 13 1.1491142428339838
#
#
# tau=17.328679513998633
#
#
# Relations for 12 in embedding using distance metric
# 1 0.9999999843188329
# 11 1.0691142277067245
# 13 1.0691142315112325
# 14 1.14911417709146
# 10 1.1491142239558774
#
#
# tau=17.328679513998633
#
#
# Relations for 13 in embedding using distance metric
# 1 1.0000000059215868
# 14 1.0691142051697107
# 12 1.0691142315112325
# 15 1.1491142143620499
# 11 1.1491142428339838
#
#
# tau=17.328679513998633
#
#
# Relations for 14 in embedding using distance metric
# 1 0.9999999579773101
# 15 1.0691141728932692
# 13 1.0691142051697107
# 16 1.1491141474308704
# 12 1.14911417709146
#
#
# tau=17.328679513998633
#
#
# Relations for 15 in embedding using distance metric
# 1 0.9999999736451463
# 16 1.0691141695742008
# 14 1.0691141728932692
# 13 1.1491142143620499
# 17 1.1491142162688919
#
#
# tau=17.328679513998633
#
#
# Relations for 16 in embedding using distance metric
# 1 0.9999999546582434
# 15 1.0691141695742008
# 17 1.069114203757486
# 14 1.1491141474308704
# 18 1.1491141769893851
#
#
# tau=17.328679513998633
#
#
# Relations for 17 in embedding using distance metric
# 1 1.000000007828429
# 16 1.069114203757486
# 18 1.0691142366350672
# 15 1.1491142162688919
# 19 1.1491142186492709
#
#
# tau=17.328679513998633
#
#
# Relations for 18 in embedding using distance metric
# 1 0.9999999875358232
# 19 1.0691142048321622
# 17 1.0691142366350672
# 20 1.1491141557524909
# 16 1.1491141769893851
#
#
# tau=17.328679513998633
#
#
# Relations for 19 in embedding using distance metric
# 1 0.9999999760255212
# 20 1.0691141507176862
# 18 1.0691142048321622
# 21 1.1491142129590994
# 17 1.1491142186492709
#
#
# tau=17.328679513998633
#
#
# Relations for 20 in embedding using distance metric
# 1 0.9999999334213504
# 19 1.0691141507176862
# 21 1.0691141768304195
# 18 1.1491141557524909
# 22 1.1491141709500907
#
#
# tau=17.328679513998633
#
#
# Relations for 21 in embedding using distance metric
# 1 1.0000000021382571
# 20 1.0691141768304195
# 22 1.069114246142496
# 23 1.1491141351130125
# 19 1.1491142129590994
#
#
# tau=17.328679513998633
#
#
# Relations for 22 in embedding using distance metric
# 1 1.0000000027334244
# 23 1.069114142183676
# 21 1.069114246142496
# 24 1.1491141492397403
# 20 1.1491141709500907
#
#
# tau=17.328679513998633
#
#
# Relations for 23 in embedding using distance metric
# 1 0.9999998981794398
# 24 1.0691140511612505
# 22 1.069114142183676
# 25 1.1491140876496857
# 21 1.1491141351130125
#
#
# tau=17.328679513998633
#
#
# Relations for 24 in embedding using distance metric
# 1 0.9999999117110022
# 23 1.0691140511612505
# 25 1.0691141076567432
# 26 1.1491140774481912
# 22 1.1491141492397403
#
#
# tau=17.328679513998633
#
#
# Relations for 25 in embedding using distance metric
# 1 0.9999999546749273
# 24 1.0691141076567432
# 26 1.069114126887622
# 23 1.1491140876496857
# 27 1.149114147473538
#
#
# tau=17.328679513998633
#
#
# Relations for 26 in embedding using distance metric
# 1 0.9999999309418836
# 25 1.069114126887622
# 27 1.0691141302159788
# 28 1.1491139879764274
# 24 1.1491140774481912
#
#
# tau=17.328679513998633
#
#
# Relations for 27 in embedding using distance metric
# 1 0.9999999580032854
# 28 1.0691140215133392
# 26 1.0691141302159788
# 25 1.149114147473538
# 29 1.1491141664738116
#
#
# tau=17.328679513998633
#
#
# Relations for 28 in embedding using distance metric
# 1 0.9999998222392374
# 27 1.0691140215133392
# 29 1.0691140371852548
# 26 1.1491139879764274
# 30 1.1491140670287254
#
#
# tau=17.328679513998633
#
#
# Relations for 29 in embedding using distance metric
# 1 0.9999999736752019
# 28 1.0691140371852548
# 30 1.0691142249401915
# 31 1.149114163165163
# 27 1.1491141664738116
#
#
# tau=17.328679513998633
#
#
# Relations for 30 in embedding using distance metric
# 1 1.0000000099941733
# 31 1.0691142059596275
# 29 1.0691142249401915
# 28 1.1491140670287254
# 32 1.1491140785570932
#
#
# tau=17.328679513998633
#
#
# Relations for 31 in embedding using distance metric
# 1 0.9999999546946369
# 32 1.069114029733059
# 30 1.0691142059596275
# 29 1.149114163165163
# 33 1.1491141973611283
#
#
# tau=17.328679513998633
#
#
# Relations for 32 in embedding using distance metric
# 1 0.999999833767611
# 31 1.069114029733059
# 33 1.069114082909587
# 34 1.1491138662638052
# 30 1.1491140785570932
#
#
# tau=17.328679513998633
#
#
# Relations for 33 in embedding using distance metric
# 1 1.0000000078711693
# 34 1.0691140468428704
# 32 1.069114082909587
# 31 1.1491141973611283
# 35 1.1491143331473002
#
#
# tau=17.328679513998633
#
#
# Relations for 34 in embedding using distance metric
# 1 0.9999997977008946
# 33 1.0691140468428704
# 35 1.0691141294525135
# 32 1.1491138662638052
# 36 1.1491139189793056
#
#
# tau=17.328679513998633
#
#
# Relations for 35 in embedding using distance metric
# 1 1.0000000904808175
# 34 1.0691141294525135
# 36 1.0691142182347277
# 33 1.1491143331473002
# 37 1.149114416718996
#
#
# tau=17.328679513998633
#
#
# Relations for 36 in embedding using distance metric
# 1 0.9999998864831199
# 35 1.0691142182347277
# 37 1.0691142191967813
# 38 1.1491138272717487
# 34 1.1491139189793056
#
#
# tau=17.328679513998633
#
#
# Relations for 37 in embedding using distance metric
# 1 1.0000000914428706
# 38 1.06911403870701
# 36 1.0691142191967813
# 39 1.1491143882645296
# 35 1.149114416718996
#
#
# tau=17.328679513998633
#
#
# Relations for 38 in embedding using distance metric
# 1 0.9999997059933383
# 39 1.069114009290492
# 37 1.06911403870701
# 40 1.1491138186404204
# 36 1.1491138272717487
#
#
# tau=17.328679513998633
#
#
# Relations for 39 in embedding using distance metric
# 1 1.0000000620263494
# 38 1.069114009290492
# 40 1.0691141811489333
# 41 1.1491138718274396
# 37 1.1491143882645296
#
#
# tau=17.328679513998633
#
#
# Relations for 40 in embedding using distance metric
# 1 0.999999877851765
# 41 1.06911369412837
# 39 1.0691141811489333
# 38 1.1491138186404204
# 42 1.1491141173813086
#
#
# tau=17.328679513998633
#
#
# Relations for 41 in embedding using distance metric
# 1 0.9999995750057818
# 40 1.06911369412837
# 42 1.0691138210108122
# 43 1.1491133416330537
# 39 1.1491138718274396
#
#
# tau=17.328679513998633
#
#
# Relations for 42 in embedding using distance metric
# 1 1.0000000047342161
# 43 1.069113777836996
# 41 1.0691138210108122
# 44 1.1491137942781606
# 40 1.1491141173813086
#
#
# tau=17.328679513998633
#
#
# Relations for 43 in embedding using distance metric
# 1 0.999999531831966
# 44 1.0691133278514104
# 42 1.069113777836996
# 41 1.1491133416330537
# 45 1.1491138372598004
#
#
# tau=17.328679513998633
#
#
# Relations for 44 in embedding using distance metric
# 1 0.9999995547486359
# 43 1.0691133278514104
# 45 1.0691138666519682
# 46 1.1491134773520728
# 42 1.1491137942781606
#
#
# tau=17.328679513998633
#
#
# Relations for 45 in embedding using distance metric
# 1 1.0000000706325265
# 44 1.0691138666519682
# 46 1.0691139997114676
# 43 1.1491138372598004
# 47 1.149113840639419
#
#
# tau=17.328679513998633
#
#
# Relations for 46 in embedding using distance metric
# 1 0.9999996878081511
# 47 1.0691134642905311
# 45 1.0691139997114676
# 44 1.1491134773520728
# 48 1.1491135820803051
#
#
# tau=17.328679513998633
#
#
# Relations for 47 in embedding using distance metric
# 1 0.9999995352115929
# 48 1.0691134359592613
# 46 1.0691134642905311
# 45 1.149113840639419
# 49 1.1491139299384883
#
#
# tau=17.328679513998633
#
#
# Relations for 48 in embedding using distance metric
# 1 0.9999996594768826
# 47 1.0691134359592613
# 49 1.069114060679266
# 46 1.1491135820803051
# 50 1.1491140251458698
#
#
# tau=17.328679513998633
#
#
# Relations for 49 in embedding using distance metric
# 1 1.000000159931601
# 48 1.069114060679266
# 50 1.0691145320760946
# 47 1.1491139299384883
# 51 1.1491143258951968
#
#
# tau=17.328679513998633
#
#
# Relations for 50 in embedding using distance metric
# 1 1.0000001308737003
# 51 1.0691143033127917
# 49 1.0691145320760946
# 52 1.1491138047330434
# 48 1.1491140251458698
#
#
# tau=17.328679513998633
#
#
# Relations for 51 in embedding using distance metric
# 1 0.9999999311682822
# 52 1.0691136115031419
# 50 1.0691143033127917
# 53 1.1491138835667116
# 49 1.1491143258951968
#
#
# tau=17.328679513998633
#
#
# Relations for 52 in embedding using distance metric
# 1 0.9999994390640514
# 53 1.0691133979379646
# 51 1.0691136115031419
# 54 1.1491137809584482
# 50 1.1491138047330434
#
#
# tau=17.328679513998633
#
#
# Relations for 53 in embedding using distance metric
# 1 0.9999997176031445
# 52 1.0691133979379646
# 54 1.0691140659730185
# 55 1.1491137749514273
# 51 1.1491138835667116
#
#
# tau=17.328679513998633
#
#
# Relations for 54 in embedding using distance metric
# 1 1.0000001070991031
# 53 1.0691140659730185
# 55 1.069114170922914
# 52 1.1491137809584482
# 56 1.149114326573712
#
#
# tau=17.328679513998633
#
#
# Relations for 55 in embedding using distance metric
# 1 0.9999998225529918
# 56 1.0691140485031174
# 54 1.069114170922914
# 57 1.1491134731599866
# 53 1.1491137749514273
#
#
# tau=17.328679513998633
#
#
# Relations for 56 in embedding using distance metric
# 1 0.9999999846792955
# 57 1.069113641761783
# 55 1.0691140485031174
# 58 1.1491141104591729
# 54 1.149114326573712
#
#
# tau=17.328679513998633
#
#
# Relations for 57 in embedding using distance metric
# 1 0.9999994158116926
# 58 1.0691135480670444
# 56 1.069113641761783
# 59 1.149113062206645
# 55 1.1491134731599866
#
#
# tau=17.328679513998633
#
#
# Relations for 58 in embedding using distance metric
# 1 0.9999998909845498
# 59 1.0691135438550432
# 57 1.0691135480670444
# 56 1.1491141104591729
# 60 1.1491142369512277
#
#
# tau=17.328679513998633
#
#
# Relations for 59 in embedding using distance metric
# 1 0.9999994115996959
# 58 1.0691135438550432
# 60 1.0691137640418351
# 57 1.149113062206645
# 61 1.1491136015508545
#
#
# tau=17.328679513998633
#
#
# Relations for 60 in embedding using distance metric
# 1 1.000000111171358
# 59 1.0691137640418351
# 61 1.0691143075980363
# 62 1.1491142304310427
# 58 1.1491142369512277
#
#
# tau=17.328679513998633
#
#
# Relations for 61 in embedding using distance metric
# 1 0.9999999551558698
# 62 1.0691140808910629
# 60 1.0691143075980363
# 59 1.1491136015508545
# 63 1.149114366368549
#
#
# tau=17.328679513998633
#
#
# Relations for 62 in embedding using distance metric
# 1 0.9999998844643654
# 61 1.0691140808910629
# 63 1.0691143021525435
# 60 1.1491142304310427
# 64 1.1491143842374907
#
#
# tau=17.328679513998633
#
#
# Relations for 63 in embedding using distance metric
# 1 1.0000001764173676
# 62 1.0691143021525435
# 64 1.0691146826659632
# 61 1.149114366368549
# 65 1.1491144196741978
#
#
# tau=17.328679513998633
#
#
# Relations for 64 in embedding using distance metric
# 1 1.000000264977815
# 65 1.0691145147101309
# 63 1.0691146826659632
# 66 1.1491142177857165
# 62 1.1491143842374907
#
#
# tau=17.328679513998633
#
#
# Relations for 65 in embedding using distance metric
# 1 1.000000008461523
# 66 1.0691139677449402
# 64 1.0691145147101309
# 63 1.1491144196741978
# 67 1.1491144293218023
#
#
# tau=17.328679513998633
#
#
# Relations for 66 in embedding using distance metric
# 1 0.9999997180125814
# 65 1.0691139677449402
# 67 1.0691141453483768
# 68 1.1491134715565228
# 64 1.1491142177857165
#
#
# tau=17.328679513998633
#
#
# Relations for 67 in embedding using distance metric
# 1 1.0000001860649717
# 68 1.069113946084382
# 66 1.0691141453483768
# 69 1.1491136890443998
# 65 1.1491144293218023
#
#
# tau=17.328679513998633
#
#
# Relations for 68 in embedding using distance metric
# 1 0.9999995187486672
# 69 1.0691130282035546
# 67 1.069113946084382
# 66 1.1491134715565228
# 70 1.1491136033378362
#
#
# tau=17.328679513998633
#
#
# Relations for 69 in embedding using distance metric
# 1 0.9999992681841717
# 68 1.0691130282035546
# 70 1.0691133592488609
# 67 1.1491136890443998
# 71 1.149113826403198
#
#
# tau=17.328679513998633
#
#
# Relations for 70 in embedding using distance metric
# 1 0.9999998497939047
# 69 1.0691133592488609
# 71 1.0691144144884854
# 68 1.1491136033378362
# 72 1.149114042824722
#
#
# tau=17.328679513998633
#
#
# Relations for 71 in embedding using distance metric
# 1 1.0000003234237784
# 70 1.0691144144884854
# 72 1.0691145229300565
# 69 1.149113826403198
# 73 1.1491146505959005
#
#
# tau=17.328679513998633
#
#
# Relations for 72 in embedding using distance metric
# 1 0.9999999582354852
# 73 1.069114291883125
# 71 1.0691145229300565
# 74 1.1491129072446016
# 70 1.149114042824722
#
#
# tau=17.328679513998633
#
#
# Relations for 73 in embedding using distance metric
# 1 1.000000092376829
# 74 1.069113047861448
# 72 1.069114291883125
# 75 1.1491140342601758
# 71 1.1491146505959005
#
#
# tau=17.328679513998633
#
#
# Relations for 74 in embedding using distance metric
# 1 0.9999987142138257
# 75 1.0691126625726652
# 73 1.069113047861448
# 76 1.1491125844911667
# 72 1.1491129072446016
#
#
# tau=17.328679513998633
#
#
# Relations for 75 in embedding using distance metric
# 1 0.9999997070880144
# 74 1.0691126625726652
# 76 1.069113583840909
# 77 1.149112977028739
# 73 1.1491140342601758
#
#
# tau=17.328679513998633
#
#
# Relations for 76 in embedding using distance metric
# 1 0.999999635482028
# 77 1.06911291189827
# 75 1.069113583840909
# 74 1.1491125844911667
# 78 1.149112606839614
#
#
# tau=17.328679513998633
#
#
# Relations for 77 in embedding using distance metric
# 1 0.9999990351454467
# 78 1.069112012978474
# 76 1.06911291189827
# 75 1.149112977028739
# 79 1.1491131491126751
#
#
# tau=17.328679513998633
#
#
# Relations for 78 in embedding using distance metric
# 1 0.9999987365622881
# 77 1.069112012978474
# 79 1.0691128570050463
# 80 1.1491124538183153
# 76 1.149112606839614
#
#
# tau=17.328679513998633
#
#
# Relations for 79 in embedding using distance metric
# 1 0.999999879171962
# 78 1.0691128570050463
# 80 1.0691136029035455
# 81 1.1491131209404677
# 77 1.1491131491126751
#
#
# tau=17.328679513998633
#
#
# Relations for 80 in embedding using distance metric
# 1 0.9999994824607198
# 81 1.0691127307047679
# 79 1.0691136029035455
# 78 1.1491124538183153
# 82 1.1491139736235363
#
#
# tau=17.328679513998633
#
#
# Relations for 81 in embedding using distance metric
# 1 0.9999990069732501
# 80 1.0691127307047679
# 82 1.069113504611466
# 83 1.149111452997219
# 79 1.1491131209404677
#
#
# tau=17.328679513998633
#
#
# Relations for 82 in embedding using distance metric
# 1 1.000000256367479
# 83 1.0691127088670185
# 81 1.069113504611466
# 80 1.1491139736235363
# 84 1.1491142711792826
#
#
# tau=17.328679513998633
#
#
# Relations for 83 in embedding using distance metric
# 1 0.9999982112287503
# 84 1.0691122325160662
# 82 1.0691127088670185
# 81 1.149111452997219
# 85 1.1491126075985616
#
#
# tau=17.328679513998633
#
#
# Relations for 84 in embedding using distance metric
# 1 0.999999780016487
# 83 1.0691122325160662
# 85 1.0691141828618362
# 86 1.1491133870844752
# 82 1.1491142711792826
#
#
# tau=17.328679513998633
#
#
# Relations for 85 in embedding using distance metric
# 1 1.0000001615745293
# 86 1.069113775117994
# 84 1.0691141828618362
# 83 1.1491126075985616
# 87 1.1491146112829294
#
#
# tau=17.328679513998633
#
#
# Relations for 86 in embedding using distance metric
# 1 0.9999993722726142
# 85 1.069113775117994
# 87 1.0691138284565667
# 84 1.1491133870844752
# 88 1.1491141181132325
#
#
# tau=17.328679513998633
#
#
# Relations for 87 in embedding using distance metric
# 1 1.0000002149131042
# 86 1.0691138284565667
# 88 1.069114967229153
# 89 1.1491124551054601
# 85 1.1491146112829294
#
#
# tau=17.328679513998633
#
#
# Relations for 88 in embedding using distance metric
# 1 1.0000005110452903
# 89 1.069112757713142
# 87 1.069114967229153
# 90 1.149113570013737
# 86 1.1491141181132325
#
#
# tau=17.328679513998633
#
#
# Relations for 89 in embedding using distance metric
# 1 0.9999980053970875
# 90 1.0691110708410694
# 88 1.069112757713142
# 91 1.1491104888095367
# 87 1.1491124551054601
#
#
# tau=17.328679513998633
#
#
# Relations for 90 in embedding using distance metric
# 1 0.9999988241732533
# 89 1.0691110708410694
# 91 1.069111314061181
# 92 1.1491131398479126
# 88 1.149113570013737
#
#
# tau=17.328679513998633
#
#
# Relations for 91 in embedding using distance metric
# 1 0.9999982486172255
# 90 1.069111314061181
# 92 1.0691125707674365
# 89 1.1491104888095367
# 93 1.1491120212394113
#
#
# tau=17.328679513998633
#
#
# Relations for 92 in embedding using distance metric
# 1 1.000000080879437
# 91 1.0691125707674365
# 93 1.0691138599771766
# 90 1.1491131398479126
# 94 1.1491150644175216
#
#
# tau=17.328679513998633
#
#
# Relations for 93 in embedding using distance metric
# 1 0.9999995378268959
# 92 1.0691138599771766
# 94 1.0691145278405072
# 91 1.1491120212394113
# 95 1.1491126486597065
#
#
# tau=17.328679513998633
#
#
# Relations for 94 in embedding using distance metric
# 1 1.0000007487428189
# 95 1.0691138660510526
# 93 1.0691145278405072
# 96 1.1491133781387775
# 92 1.1491150644175216
#
#
# tau=17.328679513998633
#
#
# Relations for 95 in embedding using distance metric
# 1 0.9999988760375761
# 96 1.0691115119089978
# 94 1.0691138660510526
# 97 1.1491108135432655
# 93 1.1491126486597065
#
#
# tau=17.328679513998633
#
#
# Relations for 96 in embedding using distance metric
# 1 0.9999983946007763
# 97 1.0691103385820415
# 95 1.0691115119089978
# 98 1.1491111257201452
# 94 1.1491133781387775
#
#
# tau=17.328679513998633
#
#
# Relations for 97 in embedding using distance metric
# 1 0.9999977027105345
# 96 1.0691103385820415
# 98 1.0691104403054905
# 95 1.1491108135432655
# 99 1.1491112170082414
#
#
# tau=17.328679513998633
#
#
# Relations for 98 in embedding using distance metric
# 1 0.9999984963242408
# 97 1.0691104403054905
# 99 1.069112017097418
# 96 1.1491111257201452
# 100 1.1491112404396835
#
#
# tau=17.328679513998633
#
#
# Relations for 99 in embedding using distance metric
# 1 0.9999992795023886
# 98 1.069112017097418
# 100 1.0691120300935057
# 97 1.1491112170082414
# 101 1.1491116694032406
#
#
# tau=17.328679513998633
#
#
# Relations for 100 in embedding using distance metric
# 1 0.999998509320338
# 101 1.0691109056965706
# 99 1.0691120300935057
# 98 1.1491112404396835
# 102 1.1491131694308538
#
#
# tau=17.328679513998633
#
#
# Relations for 101 in embedding using distance metric
# 1 0.9999981551055799
# 100 1.0691109056965706
# 102 1.0691128216916297
# 99 1.1491116694032406
# 103 1.1491127586597567
#
#
# tau=17.328679513998633
#
#
# Relations for 102 in embedding using distance metric
# 1 1.000000425315336
# 101 1.0691128216916297
# 103 1.0691150353450631
# 100 1.1491131694308538
# 104 1.1491149159647847
#
#
# tau=17.328679513998633
#
#
# Relations for 103 in embedding using distance metric
# 1 1.0000003687589742
# 104 1.0691148658839136
# 102 1.0691150353450631
# 101 1.1491127586597567
# 105 1.1491133629621308
#
#
# tau=17.328679513998633
#
#
# Relations for 104 in embedding using distance metric
# 1 1.000000255854173
# 105 1.0691132565328458
# 103 1.0691148658839136
# 106 1.1491129283810009
# 102 1.1491149159647847
#
#
# tau=17.328679513998633
#
#
# Relations for 105 in embedding using distance metric
# 1 0.9999987594080104
# 106 1.0691114384102376
# 104 1.0691132565328458
# 107 1.1491111062361512
# 103 1.1491133629621308
#
#
# tau=17.328679513998633
#
#
# Relations for 106 in embedding using distance metric
# 1 0.9999984377316581
# 107 1.0691107910353561
# 105 1.0691114384102376
# 104 1.1491129283810009
# 108 1.1491133166551524
#
#
# tau=17.328679513998633
#
#
# Relations for 107 in embedding using distance metric
# 1 0.9999981120330889
# 106 1.0691107910353561
# 108 1.0691129974321125
# 105 1.1491111062361512
# 109 1.1491132120397756
#
#
# tau=17.328679513998633
#
#
# Relations for 108 in embedding using distance metric
# 1 1.00000064412835
# 107 1.0691129974321125
# 109 1.0691157506105868
# 110 1.1491123751554548
# 106 1.1491133166551524
#
#
# tau=17.328679513998633
#
#
# Relations for 109 in embedding using distance metric
# 1 1.0000008652115397
# 110 1.0691126027141473
# 108 1.0691157506105868
# 111 1.1491129366803714
# 107 1.1491132120397756
#
#
# tau=17.328679513998633
#
#
# Relations for 110 in embedding using distance metric
# 1 0.9999974962319191
# 111 1.0691095741762737
# 109 1.0691126027141473
# 108 1.1491123751554548
# 112 1.1491127420192324
#
#
# tau=17.328679513998633
#
#
# Relations for 111 in embedding using distance metric
# 1 0.999997836673686
# 110 1.0691095741762737
# 112 1.0691130889364848
# 113 1.1491092608832303
# 109 1.1491129366803714
#
#
# tau=17.328679513998633
#
#
# Relations for 112 in embedding using distance metric
# 1 1.000001010992149
# 113 1.0691124416772642
# 111 1.0691130889364848
# 110 1.1491127420192324
# 114 1.149113843650731
#
#
# tau=17.328679513998633
#
#
# Relations for 113 in embedding using distance metric
# 1 0.9999971894144284
# 114 1.069110028548543
# 112 1.0691124416772642
# 111 1.1491092608832303
# 115 1.1491113211645596
#
#
# tau=17.328679513998633
#
#
# Relations for 114 in embedding using distance metric
# 1 0.9999985978635086
# 113 1.069110028548543
# 115 1.0691127360890587
# 116 1.149112939219614
# 112 1.149113843650731
#
#
# tau=17.328679513998633
#
#
# Relations for 115 in embedding using distance metric
# 1 0.9999998969548913
# 114 1.0691127360890587
# 116 1.069114244786681
# 113 1.1491113211645596
# 117 1.149112352737732
#
#
# tau=17.328679513998633
#
#
# Relations for 116 in embedding using distance metric
# 1 1.0000001065609743
# 117 1.0691125688193195
# 115 1.069114244786681
# 118 1.149112421907175
# 114 1.149112939219614
#
#
# tau=17.328679513998633
#
#
# Relations for 117 in embedding using distance metric
# 1 0.9999982209876849
# 118 1.0691105428092653
# 116 1.0691125688193195
# 119 1.1491113349256308
# 115 1.149112352737732
#
#
# tau=17.328679513998633
#
#
# Relations for 118 in embedding using distance metric
# 1 0.999998080551055
# 117 1.0691105428092653
# 119 1.0691112009645407
# 120 1.1491121047118453
# 116 1.149112421907175
#
#
# tau=17.328679513998633
#
#
# Relations for 119 in embedding using distance metric
# 1 0.9999988791427272
# 118 1.0691112009645407
# 120 1.0691129097792715
# 117 1.1491113349256308
# 121 1.1491130763967015
#
#
# tau=17.328679513998633
#
#
# Relations for 120 in embedding using distance metric
# 1 0.9999997893656251
# 119 1.0691129097792715
# 121 1.0691139930950393
# 118 1.1491121047118453
# 122 1.149112552505823
#
#
# tau=17.328679513998633
#
#
# Relations for 121 in embedding using distance metric
# 1 0.9999999624585793
# 122 1.0691127320742817
# 120 1.0691139930950393
# 119 1.1491130763967015
# 123 1.1491140895454315
#
#
# tau=17.328679513998633
#
#
# Relations for 122 in embedding using distance metric
# 1 0.9999985283450804
# 123 1.06911266190723
# 121 1.0691127320742817
# 124 1.1491107823515745
# 120 1.149112552505823
#
#
# tau=17.328679513998633
#
#
# Relations for 123 in embedding using distance metric
# 1 0.9999998922915236
# 124 1.0691121527737653
# 122 1.06911266190723
# 125 1.1491115759354176
# 121 1.1491140895454315
#
#
# tau=17.328679513998633
#
#
# Relations for 124 in embedding using distance metric
# 1 0.9999980192115846
# 125 1.0691097093308337
# 123 1.0691121527737653
# 126 1.1491097476459382
# 122 1.1491107823515745
#
#
# tau=17.328679513998633
#
#
# Relations for 125 in embedding using distance metric
# 1 0.9999974488487297
# 126 1.069109183758678
# 124 1.0691097093308337
# 127 1.149109132645683
# 123 1.1491115759354176
#
#
# tau=17.328679513998633
#
#
# Relations for 126 in embedding using distance metric
# 1 0.9999974936393988
# 125 1.069109183758678
# 127 1.0691091839119073
# 128 1.149108321741542
# 124 1.1491097476459382
#
#
# tau=17.328679513998633
#
#
# Relations for 127 in embedding using distance metric
# 1 0.9999974490019705
# 128 1.0691082835796872
# 126 1.0691091839119073
# 125 1.149109132645683
# 129 1.1491117016877486
#
#
# tau=17.328679513998633
#
#
# Relations for 128 in embedding using distance metric
# 1 0.999996593307119
# 127 1.0691082835796872
# 129 1.069110852468489
# 126 1.149108321741542
# 130 1.14911214789581
#
#
# tau=17.328679513998633
#
#
# Relations for 129 in embedding using distance metric
# 1 1.0000000178906323
# 128 1.069110852468489
# 130 1.0691155789549223
# 127 1.1491117016877486
# 131 1.149113980851996
#
#
# tau=17.328679513998633
#
#
# Relations for 130 in embedding using distance metric
# 1 1.0000013197935784
# 131 1.0691152892303393
# 129 1.0691155789549223
# 128 1.14911214789581
# 132 1.149116116471976
#
#
# tau=17.328679513998633
#
#
# Relations for 131 in embedding using distance metric
# 1 0.9999997281660278
# 132 1.069114531320019
# 130 1.0691152892303393
# 133 1.149111059627484
# 129 1.149113980851996
#
#
# tau=17.328679513998633
#
#
# Relations for 132 in embedding using distance metric
# 1 1.000000561883199
# 133 1.0691118998201288
# 131 1.069114531320019
# 134 1.1491158979831946
# 130 1.149116116471976
#
#
# tau=17.328679513998633
#
#
# Relations for 133 in embedding using distance metric
# 1 0.9999970966663031
# 132 1.0691118998201288
# 134 1.0691124392416718
# 135 1.1491108617521855
# 131 1.149111059627484
#
#
# tau=17.328679513998633
#
#
# Relations for 134 in embedding using distance metric
# 1 1.000001101304782
# 133 1.0691124392416718
# 135 1.0691148728662627
# 136 1.1491133551138935
# 132 1.1491158979831946
#
#
# tau=17.328679513998633
#
#
# Relations for 135 in embedding using distance metric
# 1 0.9999995302907162
# 136 1.0691117905754575
# 134 1.0691148728662627
# 137 1.1491097550870528
# 133 1.1491108617521855
#
#
# tau=17.328679513998633
#
#
# Relations for 136 in embedding using distance metric
# 1 0.9999980190141227
# 137 1.0691082502857454
# 135 1.0691117905754575
# 138 1.1491117848758223
# 134 1.1491133551138935
#
#
# tau=17.328679513998633
#
#
# Relations for 137 in embedding using distance metric
# 1 0.9999959900011225
# 136 1.0691082502857454
# 138 1.069109762338503
# 135 1.1491097550870528
# 139 1.1491117814785101
#
#
# tau=17.328679513998633
#
#
# Relations for 138 in embedding using distance metric
# 1 0.9999995310666093
# 137 1.069109762338503
# 139 1.0691153290196422
# 136 1.1491117848758223
# 140 1.1491152187902296
#
#
# tau=17.328679513998633
#
#
# Relations for 139 in embedding using distance metric
# 1 1.0000015566823028
# 138 1.0691153290196422
# 140 1.0691172508812483
# 137 1.1491117814785101
# 141 1.1491143847785152
#
#
# tau=17.328679513998633
#
#
# Relations for 140 in embedding using distance metric
# 1 1.0000014529283632
# 141 1.0691142875000754
# 139 1.0691172508812483
# 142 1.1491151000373676
# 138 1.1491152187902296
#
#
# tau=17.328679513998633
#
#
# Relations for 141 in embedding using distance metric
# 1 0.9999985933009028
# 142 1.0691122468856138
# 140 1.0691142875000754
# 143 1.1491092135179124
# 139 1.1491143847785152
#
#
# tau=17.328679513998633
#
#
# Relations for 142 in embedding using distance metric
# 1 0.9999994123137411
# 143 1.069110039006251
# 141 1.0691122468856138
# 144 1.1491097725679456
# 140 1.1491151000373676
#
#
# tau=17.328679513998633
#
#
# Relations for 143 in embedding using distance metric
# 1 0.9999963854217949
# 144 1.0691067521513602
# 142 1.069110039006251
# 145 1.149108883217875
# 141 1.1491092135179124
#
#
# tau=17.328679513998633
#
#
# Relations for 144 in embedding using distance metric
# 1 0.9999961254590328
# 143 1.0691067521513602
# 145 1.0691086297306949
# 146 1.1491053001950586
# 142 1.1491097725679456
#
#
# tau=17.328679513998633
#
#
# Relations for 145 in embedding using distance metric
# 1 0.9999982630008469
# 146 1.0691074442127584
# 144 1.0691086297306949
# 143 1.149108883217875
# 147 1.149113124656958
#
#
# tau=17.328679513998633
#
#
# Relations for 146 in embedding using distance metric
# 1 0.9999949399410129
# 145 1.0691074442127584
# 147 1.069109808072446
# 144 1.1491053001950586
# 148 1.1491090380617737
#
#
# tau=17.328679513998633
#
#
# Relations for 147 in embedding using distance metric
# 1 1.0000006268607184
# 146 1.069109808072446
# 148 1.0691147314570477
# 145 1.149113124656958
# 149 1.1491145857594571
#
#
# tau=17.328679513998633
#
#
# Relations for 148 in embedding using distance metric
# 1 0.9999998633255538
# 149 1.0691138286998432
# 147 1.0691147314570477
# 146 1.1491090380617737
# 150 1.1491138931625484
#
#
# tau=17.328679513998633
#
#
# Relations for 149 in embedding using distance metric
# 1 0.9999997241034421
# 150 1.0691137604159464
# 148 1.0691138286998432
# 151 1.149113612369931
# 147 1.1491145857594571
#
#
# tau=17.328679513998633
#
#
# Relations for 150 in embedding using distance metric
# 1 0.9999997950416532
# 151 1.069113689783642
# 149 1.0691137604159464
# 152 1.1491128980445824
# 148 1.1491138931625484
#
#
# tau=17.328679513998633
#
#
# Relations for 151 in embedding using distance metric
# 1 0.9999996534711292
# 152 1.0691127629495814
# 150 1.069113689783642
# 153 1.14911088785098
# 149 1.149113612369931
#
#
# tau=17.328679513998633
#
#
# Relations for 152 in embedding using distance metric
# 1 0.9999988682075238
# 153 1.0691101090629782
# 151 1.0691127629495814
# 150 1.1491128980445824
# 154 1.149115030368473
#
#
# tau=17.328679513998633
#
#
# Relations for 153 in embedding using distance metric
# 1 0.9999969995848058
# 152 1.0691101090629782
# 154 1.0691131682208923
# 155 1.1491078822000582
# 151 1.14911088785098
#
#
# tau=17.328679513998633
#
#
# Relations for 154 in embedding using distance metric
# 1 1.0000019273656797
# 155 1.0691128164566213
# 153 1.0691131682208923
# 156 1.1491136245067113
# 152 1.149115030368473
#
#
# tau=17.328679513998633
#
#
# Relations for 155 in embedding using distance metric
# 1 0.9999966478205198
# 156 1.069108351436963
# 154 1.0691128164566213
# 157 1.1491064539871252
# 153 1.1491078822000582
#
#
# tau=17.328679513998633
#
#
# Relations for 156 in embedding using distance metric
# 1 0.999997462346182
# 157 1.0691072749883161
# 155 1.069108351436963
# 158 1.149110960382107
# 154 1.1491136245067113
#
#
# tau=17.328679513998633
#
#
# Relations for 157 in embedding using distance metric
# 1 0.9999955713718064
# 156 1.0691072749883161
# 158 1.069109075883412
# 155 1.1491064539871252
# 159 1.1491093108411221
#
#
# tau=17.328679513998633
#
#
# Relations for 158 in embedding using distance metric
# 1 0.9999992632409059
# 157 1.069109075883412
# 159 1.0691130091860133
# 160 1.149109298607452
# 156 1.149110960382107
#
#
# tau=17.328679513998633
#
#
# Relations for 159 in embedding using distance metric
# 1 0.9999995046741961
# 160 1.0691095465162859
# 158 1.0691130091860133
# 157 1.1491093108411221
# 161 1.1491104934276357
#
#
# tau=17.328679513998633
#
#
# Relations for 160 in embedding using distance metric
# 1 0.9999958005714452
# 161 1.0691067958001814
# 159 1.0691095465162859
# 158 1.149109298607452
# 162 1.1491122305916572
#
#
# tau=17.328679513998633
#
#
# Relations for 161 in embedding using distance metric
# 1 0.9999967539584217
# 160 1.0691067958001814
# 162 1.069113190454074
# 163 1.149104267619198
# 159 1.1491104934276357
#
#
# tau=17.328679513998633
#
#
# Relations for 162 in embedding using distance metric
# 1 1.0000021952253004
# 163 1.0691097153618276
# 161 1.069113190454074
# 160 1.1491122305916572
# 164 1.149113916611231
#
#
# tau=17.328679513998633
#
#
# Relations for 163 in embedding using distance metric
# 1 0.9999932788659183
# 164 1.0691050067274865
# 162 1.0691097153618276
# 165 1.1491033597048421
# 161 1.149104267619198
#
#
# tau=17.328679513998633
#
#
# Relations for 164 in embedding using distance metric
# 1 0.9999974865911522
# 163 1.0691050067274865
# 165 1.0691075739053801
# 166 1.1491092227519804
# 162 1.149113916611231
#
#
# tau=17.328679513998633
#
#
# Relations for 165 in embedding using distance metric
# 1 0.9999958460440339
# 164 1.0691075739053801
# 166 1.069107588680549
# 163 1.1491033597048421
# 167 1.1491123382749182
#
#
# tau=17.328679513998633
#
#
# Relations for 166 in embedding using distance metric
# 1 0.9999975013663289
# 165 1.069107588680549
# 167 1.0691140000725978
# 164 1.1491092227519804
# 168 1.1491117300922071
#
#
# tau=17.328679513998633
#
#
# Relations for 167 in embedding using distance metric
# 1 1.0000022574360115
# 166 1.0691140000725978
# 168 1.0691164926376253
# 165 1.1491123382749182
# 169 1.1491166816783578
#
#
# tau=17.328679513998633
#
#
# Relations for 168 in embedding using distance metric
# 1 0.9999999939309754
# 169 1.0691144246489601
# 167 1.0691164926376253
# 170 1.1491067034915006
# 166 1.1491117300922071
#
#
# tau=17.328679513998633
#
#
# Relations for 169 in embedding using distance metric
# 1 1.0000001894471848
# 170 1.0691069054832907
# 168 1.0691144246489601
# 171 1.1491112564299755
# 167 1.1491166816783578
#
#
# tau=17.328679513998633
#
#
# Relations for 170 in embedding using distance metric
# 1 0.99999247476533
# 171 1.0691035482236522
# 169 1.0691069054832907
# 172 1.1490993135281495
# 168 1.1491067034915006
#
#
# tau=17.328679513998633
#
#
# Relations for 171 in embedding using distance metric
# 1 0.9999968321878933
# 170 1.0691035482236522
# 172 1.0691036774260625
# 169 1.1491112564299755
# 173 1.1491113124854644
#
#
# tau=17.328679513998633
#
#
# Relations for 172 in embedding using distance metric
# 1 0.9999926039677679
# 171 1.0691036774260625
# 173 1.069107090741195
# 170 1.1490993135281495
# 174 1.149105444244072
#
#
# tau=17.328679513998633
#
#
# Relations for 173 in embedding using distance metric
# 1 1.0000002455026773
# 172 1.069107090741195
# 174 1.0691130922546215
# 171 1.1491113124854644
# 175 1.149112331002652
#
#
# tau=17.328679513998633
#
#
# Relations for 174 in embedding using distance metric
# 1 0.9999986054810418
# 175 1.0691106974566649
# 173 1.0691130922546215
# 172 1.149105444244072
# 176 1.1491105834416728
#
#
# tau=17.328679513998633
#
#
# Relations for 175 in embedding using distance metric
# 1 0.9999978507045342
# 176 1.069109835140769
# 174 1.0691106974566649
# 177 1.149110126127227
# 173 1.149112331002652
#
#
# tau=17.328679513998633
#
#
# Relations for 176 in embedding using distance metric
# 1 0.9999977431650777
# 175 1.069109835140769
# 177 1.0691100250633312
# 178 1.149110474566663
# 174 1.1491105834416728
#
#
# tau=17.328679513998633
#
#
# Relations for 177 in embedding using distance metric
# 1 0.9999980406271083
# 176 1.0691100250633312
# 178 1.0691107785042149
# 175 1.149110126127227
# 179 1.1491111357791606
#
#
# tau=17.328679513998633
#
#
# Relations for 178 in embedding using distance metric
# 1 0.999998496606023
# 177 1.0691107785042149
# 179 1.0691115982335757
# 176 1.149110474566663
# 180 1.1491116082730832
#
#
# tau=17.328679513998633
#
#
# Relations for 179 in embedding using distance metric
# 1 0.9999988603565354
# 178 1.0691115982335757
# 180 1.0691119784991008
# 177 1.1491111357791606
# 181 1.1491113820443979
#
#
# tau=17.328679513998633
#
#
# Relations for 180 in embedding using distance metric
# 1 0.9999988768715719
# 181 1.0691114050349653
# 179 1.0691119784991008
# 182 1.1491099385975216
# 178 1.1491116082730832
#
#
# tau=17.328679513998633
#
#
# Relations for 181 in embedding using distance metric
# 1 0.9999982868923584
# 182 1.0691093550939075
# 180 1.0691114050349653
# 183 1.1491067509898558
# 179 1.1491113820443979
#
#
# tau=17.328679513998633
#
#
# Relations for 182 in embedding using distance metric
# 1 0.9999968269310493
# 183 1.0691052975035602
# 181 1.0691093550939075
# 180 1.1491099385975216
# 184 1.1491131934672418
#
#
# tau=17.328679513998633
#
#
# Relations for 183 in embedding using distance metric
# 1 0.9999942293024012
# 182 1.0691052975035602
# 184 1.0691106023143002
# 185 1.1491050324915155
# 181 1.1491067509898558
#
#
# tau=17.328679513998633
#
#
# Relations for 184 in embedding using distance metric
# 1 1.0000021317415002
# 183 1.0691106023143002
# 185 1.0691129414063216
# 182 1.1491131934672418
# 186 1.149117577297301
#
#
# tau=17.328679513998633
#
#
# Relations for 185 in embedding using distance metric
# 1 0.9999965683946226
# 186 1.0691120204255866
# 184 1.0691129414063216
# 187 1.1491023662398865
# 183 1.1491050324915155
#
#
# tau=17.328679513998633
#
#
# Relations for 186 in embedding using distance metric
# 1 1.0000012107606955
# 187 1.0691070150819713
# 185 1.0691120204255866
# 188 1.1491072572853214
# 184 1.149117577297301
#
#
# tau=17.328679513998633
#
#
# Relations for 187 in embedding using distance metric
# 1 0.9999915630506362
# 188 1.069097616050868
# 186 1.0691070150819713
# 185 1.1491023662398865
# 189 1.1491078610988992
#
#
# tau=17.328679513998633
#
#
# Relations for 188 in embedding using distance metric
# 1 0.9999918117296014
# 187 1.069097616050868
# 189 1.0691081162534188
# 190 1.1491030650897274
# 186 1.1491072572853214
#
#
# tau=17.328679513998633
#
#
# Relations for 189 in embedding using distance metric
# 1 1.0000020632532678
# 188 1.0691081162534188
# 190 1.0691133230889833
# 187 1.1491078610988992
# 191 1.1491179493204424
#
#
# tau=17.328679513998633
#
#
# Relations for 190 in embedding using distance metric
# 1 0.999997018564833
# 191 1.0691129111078481
# 189 1.0691133230889833
# 188 1.1491030650897274
# 192 1.1491143438131413
#
#
# tau=17.328679513998633
#
#
# Relations for 191 in embedding using distance metric
# 1 1.0000016512720928
# 190 1.0691129111078481
# 192 1.0691189829955345
# 193 1.1491169158691372
# 189 1.1491179493204424
#
#
# tau=17.328679513998633
#
#
# Relations for 192 in embedding using distance metric
# 1 1.000003090452992
# 193 1.06911836152538
# 191 1.0691189829955345
# 194 1.1491124846564007
# 190 1.1491143438131413
#
#
# tau=17.328679513998633
#
#
# Relations for 193 in embedding using distance metric
# 1 1.0000010298018973
# 194 1.069110430480988
# 192 1.06911836152538
# 195 1.1491138120701125
# 191 1.1491169158691372
#
#
# tau=17.328679513998633
#
#
# Relations for 194 in embedding using distance metric
# 1 0.9999951594087678
# 195 1.0691079481521495
# 193 1.069110430480988
# 196 1.1491071628810046
# 192 1.1491124846564007
#
#
# tau=17.328679513998633
#
#
# Relations for 195 in embedding using distance metric
# 1 0.9999985474728675
# 194 1.0691079481521495
# 196 1.0691105574212199
# 197 1.149105284560096
# 193 1.1491138120701125
#
#
# tau=17.328679513998633
#
#
# Relations for 196 in embedding using distance metric
# 1 0.9999977686772545
# 197 1.0691045122401612
# 195 1.0691105574212199
# 194 1.1491071628810046
# 198 1.149108225369523
#
#
# tau=17.328679513998633
#
#
# Relations for 197 in embedding using distance metric
# 1 0.9999925022921499
# 198 1.0691029654595896
# 196 1.0691045122401612
# 199 1.1491018169565017
# 195 1.149105284560096
#
#
# tau=17.328679513998633
#
#
# Relations for 198 in embedding using distance metric
# 1 0.9999962218973849
# 197 1.0691029654595896
# 199 1.0691055430371026
# 196 1.149108225369523
# 200 1.149113281914368
#
#
# tau=17.328679513998633
#
#
# Relations for 199 in embedding using distance metric
# 1 0.9999950798698796
# 198 1.0691055430371026
# 200 1.0691121463624502
# 201 1.149100416974447
# 197 1.1491018169565017
#
#
# tau=17.328679513998633
#
#
# Relations for 200 in embedding using distance metric
# 1 1.0000028252224245
# 201 1.0691081688029025
# 199 1.0691121463624502
# 198 1.149113281914368
# 202 1.1491193000199424
#
#
# tau=17.328679513998633
#
#
# Relations for 201 in embedding using distance metric
# 1 0.9999911023100421
# 202 1.0691075835830521
# 200 1.0691081688029025
# 203 1.1490985666475098
# 199 1.149100416974447
#
#
# tau=17.328679513998633
#
#
# Relations for 202 in embedding using distance metric
# 1 1.0000022400025228
# 201 1.0691075835830521
# 203 1.0691097108156782
# 204 1.149109073212449
# 200 1.1491193000199424
#
#
# tau=17.328679513998633
#
#
# Relations for 203 in embedding using distance metric
# 1 0.999993229542855
# 204 1.0691000692281802
# 202 1.0691097108156782
# 201 1.1490985666475098
# 205 1.1491078935477164
#
#
# tau=17.328679513998633
#
#
# Relations for 204 in embedding using distance metric
# 1 0.9999925984151505
# 203 1.0691000692281802
# 205 1.0691072688956347
# 206 1.149108697064759
# 202 1.149109073212449
#
#
# tau=17.328679513998633
#
#
# Relations for 205 in embedding using distance metric
# 1 1.0000004292100009
# 204 1.0691072688956347
# 206 1.0691165343354458
# 203 1.1491078935477164
# 207 1.149111210966028
#
#
# tau=17.328679513998633
#
#
# Relations for 206 in embedding using distance metric
# 1 1.0000018638548058
# 207 1.0691126520862548
# 205 1.0691165343354458
# 204 1.149108697064759
# 208 1.1491154523272802
#
#
# tau=17.328679513998633
#
#
# Relations for 207 in embedding using distance metric
# 1 0.9999965469605145
# 208 1.069110141908883
# 206 1.0691126520862548
# 209 1.1491057629630093
# 205 1.149111210966028
#
#
# tau=17.328679513998633
#
#
# Relations for 208 in embedding using distance metric
# 1 0.9999993536772342
# 209 1.069108576155122
# 207 1.069110141908883
# 210 1.1491121816735599
# 206 1.1491154523272802
#
#
# tau=17.328679513998633
#
#
# Relations for 209 in embedding using distance metric
# 1 0.9999949812075462
# 210 1.0691078156788139
# 208 1.069108576155122
# 211 1.149103804301338
# 207 1.1491057629630093
#
#
# tau=17.328679513998633
#
#
# Relations for 210 in embedding using distance metric
# 1 0.9999985932008739
# 211 1.06910742277094
# 209 1.0691078156788139
# 212 1.1491112498118983
# 208 1.1491121816735599
#
#
# tau=17.328679513998633
#
#
# Relations for 211 in embedding using distance metric
# 1 0.999994588299656
# 212 1.0691072513855913
# 210 1.06910742277094
# 213 1.149103013851044
# 209 1.149103804301338
#
#
# tau=17.328679513998633
#
#
# Relations for 212 in embedding using distance metric
# 1 0.9999984218155133
# 213 1.069106853843186
# 211 1.0691072513855913
# 214 1.1491103016000461
# 210 1.1491112498118983
#
#
# tau=17.328679513998633
#
#
# Relations for 213 in embedding using distance metric
# 1 0.9999941907572361
# 214 1.0691060770166916
# 212 1.069106853843186
# 215 1.1491010027135977
# 211 1.149103013851044
#
#
# tau=17.328679513998633
#
#
# Relations for 214 in embedding using distance metric
# 1 0.9999976449889618
# 215 1.0691044634216842
# 213 1.0691060770166916
# 216 1.1491069140653687
# 212 1.1491103016000461
#
#
# tau=17.328679513998633
#
#
# Relations for 215 in embedding using distance metric
# 1 0.9999925771621171
# 216 1.0691018527135407
# 214 1.0691044634216842
# 217 1.1490953142559321
# 213 1.1491010027135977
#
#
# tau=17.328679513998633
#
#
# Relations for 216 in embedding using distance metric
# 1 0.9999950342815958
# 217 1.0690977778509598
# 215 1.0691018527135407
# 218 1.1490985966918958
# 214 1.1491069140653687
#
#
# tau=17.328679513998633
#
#
# Relations for 217 in embedding using distance metric
# 1 0.9999885022992419
# 218 1.0690920711857463
# 216 1.0690977778509598
# 215 1.1490953142559321
# 219 1.1491003155766366
#
#
# tau=17.328679513998633
#
#
# Relations for 218 in embedding using distance metric
# 1 0.9999893276159572
# 217 1.0690920711857463
# 219 1.0691011473689631
# 216 1.1490985966918958
# 220 1.1490998378296007
#
#
# tau=17.328679513998633
#
#
# Relations for 219 in embedding using distance metric
# 1 0.9999975784821717
# 218 1.0691011473689631
# 220 1.0691080951718617
# 217 1.1491003155766366
# 221 1.1491140360555978
#
#
# tau=17.328679513998633
#
#
# Relations for 220 in embedding using distance metric
# 1 0.9999962754183983
# 219 1.0691080951718617
# 221 1.0691127394674247
# 218 1.1490998378296007
# 222 1.149108635273054
#
#
# tau=17.328679513998633
#
#
# Relations for 221 in embedding using distance metric
# 1 1.0000022227780925
# 220 1.0691127394674247
# 222 1.0691145891078553
# 219 1.1491140360555978
# 223 1.1491175526375754
#
#
# tau=17.328679513998633
#
#
# Relations for 222 in embedding using distance metric
# 1 0.9999981250589771
# 223 1.0691134613942312
# 221 1.0691145891078553
# 224 1.1491058800464802
# 220 1.149108635273054
#
#
# tau=17.328679513998633
#
#
# Relations for 223 in embedding using distance metric
# 1 1.000001095064376
# 224 1.0691088565272553
# 222 1.0691134613942312
# 225 1.1491081527240075
# 221 1.1491175526375754
#
#
# tau=17.328679513998633
#
#
# Relations for 224 in embedding using distance metric
# 1 0.9999935201927
# 225 1.0691005843274437
# 223 1.0691088565272553
# 222 1.1491058800464802
# 226 1.1491068193632055
#
#
# tau=17.328679513998633
#
#
# Relations for 225 in embedding using distance metric
# 1 0.9999928228649838
# 224 1.0691005843274437
# 226 1.0691061285111276
# 227 1.1491012105181146
# 223 1.1491081527240075
#
#
# tau=17.328679513998633
#
#
# Relations for 226 in embedding using distance metric
# 1 0.9999990643757647
# 225 1.0691061285111276
# 227 1.0691074585051472
# 224 1.1491068193632055
# 228 1.1491092810121954
#
#
# tau=17.328679513998633
#
#
# Relations for 227 in embedding using distance metric
# 1 0.9999941528591216
# 228 1.0691043759704113
# 226 1.0691074585051472
# 225 1.1491012105181146
# 229 1.1491129990342546
#
#
# tau=17.328679513998633
#
#
# Relations for 228 in embedding using distance metric
# 1 0.9999959818407942
# 227 1.0691043759704113
# 229 1.0691148344923838
# 226 1.1491092810121954
# 230 1.149111678108591
#
#
# tau=17.328679513998633
#
#
# Relations for 229 in embedding using distance metric
# 1 1.0000046113808148
# 228 1.0691148344923838
# 230 1.0691203141234669
# 231 1.1491049511487352
# 227 1.1491129990342546
#
#
# tau=17.328679513998633
#
#
# Relations for 230 in embedding using distance metric
# 1 1.0000014614723125
# 231 1.0691018077160994
# 229 1.0691203141234669
# 228 1.149111678108591
# 232 1.1491117305670575
#
#
# tau=17.328679513998633
#
#
# Relations for 231 in embedding using distance metric
# 1 0.9999861049731295
# 232 1.0690963805434757
# 230 1.0691018077160994
# 233 1.1490938827620136
# 229 1.1491049511487352
#
#
# tau=17.328679513998633
#
#
# Relations for 232 in embedding using distance metric
# 1 0.9999960342992656
# 231 1.0690963805434757
# 233 1.069103818564272
# 234 1.1491077548658581
# 230 1.1491117305670575
#
#
# tau=17.328679513998633
#
#
# Relations for 233 in embedding using distance metric
# 1 0.9999935429945185
# 232 1.069103818564272
# 234 1.0691052700357433
# 231 1.1490938827620136
# 235 1.1490962371725681
#
#
# tau=17.328679513998633
#
#
# Relations for 234 in embedding using distance metric
# 1 0.9999974857708572
# 235 1.06910018642548
# 233 1.0691052700357433
# 236 1.1490973652360144
# 232 1.1491077548658581
#
#
# tau=17.328679513998633
#
#
# Relations for 235 in embedding using distance metric
# 1 0.9999884593838795
# 236 1.069088345324301
# 234 1.06910018642548
# 237 1.1490917879110558
# 233 1.1490962371725681
#
#
# tau=17.328679513998633
#
#
# Relations for 236 in embedding using distance metric
# 1 0.9999856446699276
# 235 1.069088345324301
# 237 1.0690889796731122
# 234 1.1490973652360144
# 238 1.1490987401742312
#
#
# tau=17.328679513998633
#
#
# Relations for 237 in embedding using distance metric
# 1 0.999989093732757
# 236 1.0690889796731122
# 238 1.0691021957124882
# 235 1.1490917879110558
# 239 1.1490981985614468
#
#
# tau=17.328679513998633
#
#
# Relations for 238 in embedding using distance metric
# 1 0.9999988607091581
# 237 1.0691021957124882
# 239 1.0691079720139813
# 236 1.1490987401742312
# 240 1.1491100602970277
#
#
# tau=17.328679513998633
#
#
# Relations for 239 in embedding using distance metric
# 1 0.9999948700347191
# 240 1.0691060760972464
# 238 1.0691079720139813
# 241 1.1490938339791437
# 237 1.1490981985614468
#
#
# tau=17.328679513998633
#
#
# Relations for 240 in embedding using distance metric
# 1 0.9999969647922837
# 241 1.0690959352135188
# 239 1.0691060760972464
# 238 1.1491100602970277
# 242 1.1491101752785406
#
#
# tau=17.328679513998633
#
#
# Relations for 241 in embedding using distance metric
# 1 0.9999847291502191
# 240 1.0690959352135188
# 242 1.069097946111756
# 239 1.1490938339791437
# 243 1.1490976148421643
#
#
# tau=17.328679513998633
#
#
# Relations for 242 in embedding using distance metric
# 1 0.9999989756906769
# 241 1.069097946111756
# 243 1.069111867858456
# 240 1.1491101752785406
# 244 1.1491174813044447
#
#
# tau=17.328679513998633
#
#
# Relations for 243 in embedding using distance metric
# 1 0.9999986508967798
# 242 1.069111867858456
# 244 1.0691171629860259
# 241 1.1490976148421643
# 245 1.14910761388569
#
#
# tau=17.328679513998633
#
#
# Relations for 244 in embedding using distance metric
# 1 1.000004270818654
# 245 1.0691132402827068
# 243 1.0691171629860259
# 246 1.1491093868168452
# 242 1.1491174813044447
#
#
# tau=17.328679513998633
#
#
# Relations for 245 in embedding using distance metric
# 1 0.999994728193168
# 246 1.069099850667668
# 244 1.0691132402827068
# 247 1.149101738321265
# 243 1.14910761388569
#
#
# tau=17.328679513998633
#
#
# Relations for 246 in embedding using distance metric
# 1 0.9999908812038324
# 247 1.0690978978066177
# 245 1.069099850667668
# 248 1.1491055737702616
# 244 1.1491093868168452
#
#
# tau=17.328679513998633
#
#
# Relations for 247 in embedding using distance metric
# 1 0.9999927753332536
# 246 1.0690978978066177
# 248 1.0691074743751359
# 249 1.1490991327150628
# 245 1.149101738321265
#
#
# tau=17.328679513998633
#
#
# Relations for 248 in embedding using distance metric
# 1 1.0000004577718262
# 249 1.0691068216300206
# 247 1.0691074743751359
# 250 1.1491040091418878
# 246 1.1491055737702616
#
#
# tau=17.328679513998633
#
#
# Relations for 249 in embedding using distance metric
# 1 0.9999921225881073
# 250 1.069095680433146
# 248 1.0691068216300206
# 251 1.1490984408026639
# 247 1.1490991327150628
#
#
# tau=17.328679513998633
#
#
# Relations for 250 in embedding using distance metric
# 1 0.9999893165754014
# 251 1.0690956412658759
# 249 1.069095680433146
# 248 1.1491040091418878
# 252 1.1491040197885782
#
#
# tau=17.328679513998633
#
#
# Relations for 251 in embedding using distance metric
# 1 0.9999920834208507
# 250 1.0690956412658759
# 252 1.0691067931094334
# 253 1.1490982725888184
# 249 1.1490984408026639
#
#
# tau=17.328679513998633
#
#
# Relations for 252 in embedding using distance metric
# 1 1.0000004684185158
# 253 1.0691066640628697
# 251 1.0691067931094334
# 254 1.1491034926355723
# 250 1.1491040197885782
#
#
# tau=17.328679513998633
#
#
# Relations for 253 in embedding using distance metric
# 1 0.9999919543742928
# 254 1.0690949850663043
# 252 1.0691066640628697
# 255 1.149097204213996
# 251 1.1490982725888184
#
#
# tau=17.328679513998633
#
#
# Relations for 254 in embedding using distance metric
# 1 0.9999887894224022
# 255 1.069094045738065
# 253 1.0690949850663043
# 256 1.149101698447195
# ...
# 9920 1.149111452997219
# 9916 1.1491126075985616
#
#
# tau=17.328679513998633
#
#
# Relations for 9919 in embedding using distance metric
# 1 1.000000256367479
# 9918 1.0691127088670185
# 9920 1.069113504611466
# 9921 1.1491139736235363
# 9917 1.1491142711792826
#
#
# tau=17.328679513998633
#
#
# Relations for 9920 in embedding using distance metric
# 1 0.9999990069732501
# 9921 1.0691127307047679
# 9919 1.069113504611466
# 9918 1.149111452997219
# 9922 1.1491131209404677
#
#
# tau=17.328679513998633
#
#
# Relations for 9921 in embedding using distance metric
# 1 0.9999994824607198
# 9920 1.0691127307047679
# 9922 1.0691136029035455
# 9923 1.1491124538183153
# 9919 1.1491139736235363
#
#
# tau=17.328679513998633
#
#
# Relations for 9922 in embedding using distance metric
# 1 0.999999879171962
# 9923 1.0691128570050463
# 9921 1.0691136029035455
# 9920 1.1491131209404677
# 9924 1.1491131491126751
#
#
# tau=17.328679513998633
#
#
# Relations for 9923 in embedding using distance metric
# 1 0.9999987365622881
# 9924 1.069112012978474
# 9922 1.0691128570050463
# 9921 1.1491124538183153
# 9925 1.149112606839614
#
#
# tau=17.328679513998633
#
#
# Relations for 9924 in embedding using distance metric
# 1 0.9999990351454467
# 9923 1.069112012978474
# 9925 1.06911291189827
# 9926 1.149112977028739
# 9922 1.1491131491126751
#
#
# tau=17.328679513998633
#
#
# Relations for 9925 in embedding using distance metric
# 1 0.999999635482028
# 9924 1.06911291189827
# 9926 1.069113583840909
# 9927 1.1491125844911667
# 9923 1.149112606839614
#
#
# tau=17.328679513998633
#
#
# Relations for 9926 in embedding using distance metric
# 1 0.9999997070880144
# 9927 1.0691126625726652
# 9925 1.069113583840909
# 9924 1.149112977028739
# 9928 1.1491140342601758
#
#
# tau=17.328679513998633
#
#
# Relations for 9927 in embedding using distance metric
# 1 0.9999987142138257
# 9926 1.0691126625726652
# 9928 1.069113047861448
# 9925 1.1491125844911667
# 9929 1.1491129072446016
#
#
# tau=17.328679513998633
#
#
# Relations for 9928 in embedding using distance metric
# 1 1.000000092376829
# 9927 1.069113047861448
# 9929 1.069114291883125
# 9926 1.1491140342601758
# 9930 1.1491146505959005
#
#
# tau=17.328679513998633
#
#
# Relations for 9929 in embedding using distance metric
# 1 0.9999999582354852
# 9928 1.069114291883125
# 9930 1.0691145229300565
# 9927 1.1491129072446016
# 9931 1.149114042824722
#
#
# tau=17.328679513998633
#
#
# Relations for 9930 in embedding using distance metric
# 1 1.0000003234237784
# 9931 1.0691144144884854
# 9929 1.0691145229300565
# 9932 1.149113826403198
# 9928 1.1491146505959005
#
#
# tau=17.328679513998633
#
#
# Relations for 9931 in embedding using distance metric
# 1 0.9999998497939047
# 9932 1.0691133592488609
# 9930 1.0691144144884854
# 9933 1.1491136033378362
# 9929 1.149114042824722
#
#
# tau=17.328679513998633
#
#
# Relations for 9932 in embedding using distance metric
# 1 0.9999992681841717
# 9933 1.0691130282035546
# 9931 1.0691133592488609
# 9934 1.1491136890443998
# 9930 1.149113826403198
#
#
# tau=17.328679513998633
#
#
# Relations for 9933 in embedding using distance metric
# 1 0.9999995187486672
# 9932 1.0691130282035546
# 9934 1.069113946084382
# 9935 1.1491134715565228
# 9931 1.1491136033378362
#
#
# tau=17.328679513998633
#
#
# Relations for 9934 in embedding using distance metric
# 1 1.0000001860649717
# 9933 1.069113946084382
# 9935 1.0691141453483768
# 9932 1.1491136890443998
# 9936 1.1491144293218023
#
#
# tau=17.328679513998633
#
#
# Relations for 9935 in embedding using distance metric
# 1 0.9999997180125814
# 9936 1.0691139677449402
# 9934 1.0691141453483768
# 9933 1.1491134715565228
# 9937 1.1491142177857165
#
#
# tau=17.328679513998633
#
#
# Relations for 9936 in embedding using distance metric
# 1 1.000000008461523
# 9935 1.0691139677449402
# 9937 1.0691145147101309
# 9938 1.1491144196741978
# 9934 1.1491144293218023
#
#
# tau=17.328679513998633
#
#
# Relations for 9937 in embedding using distance metric
# 1 1.000000264977815
# 9936 1.0691145147101309
# 9938 1.0691146826659632
# 9935 1.1491142177857165
# 9939 1.1491143842374907
#
#
# tau=17.328679513998633
#
#
# Relations for 9938 in embedding using distance metric
# 1 1.0000001764173676
# 9939 1.0691143021525435
# 9937 1.0691146826659632
# 9940 1.149114366368549
# 9936 1.1491144196741978
#
#
# tau=17.328679513998633
#
#
# Relations for 9939 in embedding using distance metric
# 1 0.9999998844643654
# 9940 1.0691140808910629
# 9938 1.0691143021525435
# 9941 1.1491142304310427
# 9937 1.1491143842374907
#
#
# tau=17.328679513998633
#
#
# Relations for 9940 in embedding using distance metric
# 1 0.9999999551558698
# 9939 1.0691140808910629
# 9941 1.0691143075980363
# 9942 1.1491136015508545
# 9938 1.149114366368549
#
#
# tau=17.328679513998633
#
#
# Relations for 9941 in embedding using distance metric
# 1 1.000000111171358
# 9942 1.0691137640418351
# 9940 1.0691143075980363
# 9939 1.1491142304310427
# 9943 1.1491142369512277
#
#
# tau=17.328679513998633
#
#
# Relations for 9942 in embedding using distance metric
# 1 0.9999994115996959
# 9943 1.0691135438550432
# 9941 1.0691137640418351
# 9944 1.149113062206645
# 9940 1.1491136015508545
#
#
# tau=17.328679513998633
#
#
# Relations for 9943 in embedding using distance metric
# 1 0.9999998909845498
# 9942 1.0691135438550432
# 9944 1.0691135480670444
# 9945 1.1491141104591729
# 9941 1.1491142369512277
#
#
# tau=17.328679513998633
#
#
# Relations for 9944 in embedding using distance metric
# 1 0.9999994158116926
# 9943 1.0691135480670444
# 9945 1.069113641761783
# 9942 1.149113062206645
# 9946 1.1491134731599866
#
#
# tau=17.328679513998633
#
#
# Relations for 9945 in embedding using distance metric
# 1 0.9999999846792955
# 9944 1.069113641761783
# 9946 1.0691140485031174
# 9943 1.1491141104591729
# 9947 1.149114326573712
#
#
# tau=17.328679513998633
#
#
# Relations for 9946 in embedding using distance metric
# 1 0.9999998225529918
# 9945 1.0691140485031174
# 9947 1.069114170922914
# 9944 1.1491134731599866
# 9948 1.1491137749514273
#
#
# tau=17.328679513998633
#
#
# Relations for 9947 in embedding using distance metric
# 1 1.0000001070991031
# 9948 1.0691140659730185
# 9946 1.069114170922914
# 9949 1.1491137809584482
# 9945 1.149114326573712
#
#
# tau=17.328679513998633
#
#
# Relations for 9948 in embedding using distance metric
# 1 0.9999997176031445
# 9949 1.0691133979379646
# 9947 1.0691140659730185
# 9946 1.1491137749514273
# 9950 1.1491138835667116
#
#
# tau=17.328679513998633
#
#
# Relations for 9949 in embedding using distance metric
# 1 0.9999994390640514
# 9948 1.0691133979379646
# 9950 1.0691136115031419
# 9947 1.1491137809584482
# 9951 1.1491138047330434
#
#
# tau=17.328679513998633
#
#
# Relations for 9950 in embedding using distance metric
# 1 0.9999999311682822
# 9949 1.0691136115031419
# 9951 1.0691143033127917
# 9948 1.1491138835667116
# 9952 1.1491143258951968
#
#
# tau=17.328679513998633
#
#
# Relations for 9951 in embedding using distance metric
# 1 1.0000001308737003
# 9950 1.0691143033127917
# 9952 1.0691145320760946
# 9949 1.1491138047330434
# 9953 1.1491140251458698
#
#
# tau=17.328679513998633
#
#
# Relations for 9952 in embedding using distance metric
# 1 1.000000159931601
# 9953 1.069114060679266
# 9951 1.0691145320760946
# 9954 1.1491139299384883
# 9950 1.1491143258951968
#
#
# tau=17.328679513998633
#
#
# Relations for 9953 in embedding using distance metric
# 1 0.9999996594768826
# 9954 1.0691134359592613
# 9952 1.069114060679266
# 9955 1.1491135820803051
# 9951 1.1491140251458698
#
#
# tau=17.328679513998633
#
#
# Relations for 9954 in embedding using distance metric
# 1 0.9999995352115929
# 9953 1.0691134359592613
# 9955 1.0691134642905311
# 9956 1.149113840639419
# 9952 1.1491139299384883
#
#
# tau=17.328679513998633
#
#
# Relations for 9955 in embedding using distance metric
# 1 0.9999996878081511
# 9954 1.0691134642905311
# 9956 1.0691139997114676
# 9957 1.1491134773520728
# 9953 1.1491135820803051
#
#
# tau=17.328679513998633
#
#
# Relations for 9956 in embedding using distance metric
# 1 1.0000000706325265
# 9957 1.0691138666519682
# 9955 1.0691139997114676
# 9958 1.1491138372598009
# 9954 1.149113840639419
#
#
# tau=17.328679513998633
#
#
# Relations for 9957 in embedding using distance metric
# 1 0.9999995547486359
# 9958 1.0691133278514113
# 9956 1.0691138666519682
# 9955 1.1491134773520728
# 9959 1.1491137942781606
#
#
# tau=17.328679513998633
#
#
# Relations for 9958 in embedding using distance metric
# 1 0.9999995318319662
# 9957 1.0691133278514113
# 9959 1.069113777836995
# 9960 1.1491133416330532
# 9956 1.1491138372598009
#
#
# tau=17.328679513998633
#
#
# Relations for 9959 in embedding using distance metric
# 1 1.0000000047342161
# 9958 1.069113777836995
# 9960 1.0691138210108122
# 9957 1.1491137942781606
# 9961 1.1491141173813086
#
#
# tau=17.328679513998633
#
#
# Relations for 9960 in embedding using distance metric
# 1 0.9999995750057818
# 9961 1.06911369412837
# 9959 1.0691138210108122
# 9958 1.1491133416330532
# 9962 1.1491138718274396
#
#
# tau=17.328679513998633
#
#
# Relations for 9961 in embedding using distance metric
# 1 0.999999877851765
# 9960 1.06911369412837
# 9962 1.0691141811489333
# 9963 1.1491138186404208
# 9959 1.1491141173813086
#
#
# tau=17.328679513998633
#
#
# Relations for 9962 in embedding using distance metric
# 1 1.0000000620263494
# 9963 1.069114009290493
# 9961 1.0691141811489333
# 9960 1.1491138718274396
# 9964 1.1491143882645296
#
#
# tau=17.328679513998633
#
#
# Relations for 9963 in embedding using distance metric
# 1 0.9999997059933383
# 9962 1.069114009290493
# 9964 1.0691140387070093
# 9961 1.1491138186404208
# 9965 1.1491138272717485
#
#
# tau=17.328679513998633
#
#
# Relations for 9964 in embedding using distance metric
# 1 1.0000000914428706
# 9963 1.0691140387070093
# 9965 1.0691142191967813
# 9962 1.1491143882645296
# 9966 1.1491144167189962
#
#
# tau=17.328679513998633
#
#
# Relations for 9965 in embedding using distance metric
# 1 0.9999998864831199
# 9966 1.0691142182347284
# 9964 1.0691142191967813
# 9963 1.1491138272717485
# 9967 1.1491139189793056
#
#
# tau=17.328679513998633
#
#
# Relations for 9966 in embedding using distance metric
# 1 1.0000000904808175
# 9967 1.0691141294525128
# 9965 1.0691142182347284
# 9968 1.1491143331473
# 9964 1.1491144167189962
#
#
# tau=17.328679513998633
#
#
# Relations for 9967 in embedding using distance metric
# 1 0.9999997977008946
# 9968 1.0691140468428704
# 9966 1.0691141294525128
# 9969 1.1491138662638052
# 9965 1.1491139189793056
#
#
# tau=17.328679513998633
#
#
# Relations for 9968 in embedding using distance metric
# 1 1.0000000078711693
# 9967 1.0691140468428704
# 9969 1.069114082909587
# 9970 1.1491141973611283
# 9966 1.1491143331473
#
#
# tau=17.328679513998633
#
#
# Relations for 9969 in embedding using distance metric
# 1 0.999999833767611
# 9970 1.069114029733059
# 9968 1.069114082909587
# 9967 1.1491138662638052
# 9971 1.1491140785570932
#
#
# tau=17.328679513998633
#
#
# Relations for 9970 in embedding using distance metric
# 1 0.9999999546946369
# 9969 1.069114029733059
# 9971 1.0691142059596275
# 9972 1.149114163165163
# 9968 1.1491141973611283
#
#
# tau=17.328679513998633
#
#
# Relations for 9971 in embedding using distance metric
# 1 1.0000000099941733
# 9970 1.0691142059596275
# 9972 1.0691142249401915
# 9973 1.1491140670287254
# 9969 1.1491140785570932
#
#
# tau=17.328679513998633
#
#
# Relations for 9972 in embedding using distance metric
# 1 0.9999999736752019
# 9973 1.0691140371852548
# 9971 1.0691142249401915
# 9970 1.149114163165163
# 9974 1.1491141664738116
#
#
# tau=17.328679513998633
#
#
# Relations for 9973 in embedding using distance metric
# 1 0.9999998222392374
# 9974 1.0691140215133392
# 9972 1.0691140371852548
# 9975 1.1491139879764274
# 9971 1.1491140670287254
#
#
# tau=17.328679513998633
#
#
# Relations for 9974 in embedding using distance metric
# 1 0.9999999580032854
# 9973 1.0691140215133392
# 9975 1.0691141302159788
# 9976 1.149114147473538
# 9972 1.1491141664738116
#
#
# tau=17.328679513998633
#
#
# Relations for 9975 in embedding using distance metric
# 1 0.9999999309418836
# 9976 1.069114126887622
# 9974 1.0691141302159788
# 9973 1.1491139879764274
# 9977 1.1491140774481912
#
#
# tau=17.328679513998633
#
#
# Relations for 9976 in embedding using distance metric
# 1 0.9999999546749273
# 9977 1.0691141076567432
# 9975 1.069114126887622
# 9978 1.1491140876496857
# 9974 1.149114147473538
#
#
# tau=17.328679513998633
#
#
# Relations for 9977 in embedding using distance metric
# 1 0.9999999117110022
# 9978 1.0691140511612505
# 9976 1.0691141076567432
# 9975 1.1491140774481912
# 9979 1.1491141492397403
#
#
# tau=17.328679513998633
#
#
# Relations for 9978 in embedding using distance metric
# 1 0.9999998981794398
# 9977 1.0691140511612505
# 9979 1.069114142183676
# 9976 1.1491140876496857
# 9980 1.1491141351130125
#
#
# tau=17.328679513998633
#
#
# Relations for 9979 in embedding using distance metric
# 1 1.0000000027334244
# 9978 1.069114142183676
# 9980 1.069114246142496
# 9977 1.1491141492397403
# 9981 1.1491141709500907
#
#
# tau=17.328679513998633
#
#
# Relations for 9980 in embedding using distance metric
# 1 1.0000000021382571
# 9981 1.0691141768304195
# 9979 1.069114246142496
# 9978 1.1491141351130125
# 9982 1.1491142129590994
#
#
# tau=17.328679513998633
#
#
# Relations for 9981 in embedding using distance metric
# 1 0.9999999334213504
# 9982 1.0691141507176862
# 9980 1.0691141768304195
# 9983 1.1491141557524909
# 9979 1.1491141709500907
#
#
# tau=17.328679513998633
#
#
# Relations for 9982 in embedding using distance metric
# 1 0.9999999760255212
# 9981 1.0691141507176862
# 9983 1.0691142048321622
# 9980 1.1491142129590994
# 9984 1.1491142186492709
#
#
# tau=17.328679513998633
#
#
# Relations for 9983 in embedding using distance metric
# 1 0.9999999875358232
# 9982 1.0691142048321622
# 9984 1.0691142366350672
# 9981 1.1491141557524909
# 9985 1.1491141769893851
#
#
# tau=17.328679513998633
#
#
# Relations for 9984 in embedding using distance metric
# 1 1.000000007828429
# 9985 1.069114203757486
# 9983 1.0691142366350672
# 9986 1.149114216268892
# 9982 1.1491142186492709
#
#
# tau=17.328679513998633
#
#
# Relations for 9985 in embedding using distance metric
# 1 0.9999999546582434
# 9986 1.069114169574201
# 9984 1.069114203757486
# 9987 1.1491141474308704
# 9983 1.1491141769893851
#
#
# tau=17.328679513998633
#
#
# Relations for 9986 in embedding using distance metric
# 1 0.9999999736451463
# 9985 1.069114169574201
# 9987 1.069114172893269
# 9988 1.1491142143620499
# 9984 1.149114216268892
#
#
# tau=17.328679513998633
#
#
# Relations for 9987 in embedding using distance metric
# 1 0.9999999579773101
# 9986 1.069114172893269
# 9988 1.0691142051697107
# 9985 1.1491141474308704
# 9989 1.14911417709146
#
#
# tau=17.328679513998633
#
#
# Relations for 9988 in embedding using distance metric
# 1 1.0000000059215868
# 9987 1.0691142051697107
# 9989 1.0691142315112325
# 9986 1.1491142143620499
# 9990 1.149114242833984
#
#
# tau=17.328679513998633
#
#
# Relations for 9989 in embedding using distance metric
# 1 0.9999999843188329
# 9990 1.0691142277067247
# 9988 1.0691142315112325
# 9987 1.14911417709146
# 9991 1.1491142239558776
#
#
# tau=17.328679513998633
#
#
# Relations for 9990 in embedding using distance metric
# 1 1.0000000021170783
# 9989 1.0691142277067247
# 9991 1.0691142482296196
# 9992 1.1491142219275996
# 9988 1.149114242833984
#
#
# tau=17.328679513998633
#
#
# Relations for 9991 in embedding using distance metric
# 1 1.0000000048417268
# 9992 1.0691142311277437
# 9990 1.0691142482296196
# 9989 1.1491142239558776
# 9993 1.1491142306949451
#
#
# tau=17.328679513998633
#
#
# Relations for 9992 in embedding using distance metric
# 1 0.9999999850152022
# 9993 1.0691142173439159
# 9991 1.0691142311277437
# 9994 1.1491142128706375
# 9990 1.1491142219275996
#
#
# tau=17.328679513998633
#
#
# Relations for 9993 in embedding using distance metric
# 1 0.9999999910578993
# 9992 1.0691142173439159
# 9994 1.0691142253888302
# 9995 1.1491142279076445
# 9991 1.1491142306949451
#
#
# tau=17.328679513998633
#
#
# Relations for 9994 in embedding using distance metric
# 1 0.9999999930601166
# 9993 1.0691142253888302
# 9995 1.0691142363853572
# 9992 1.1491142128706375
# 9996 1.1491142241664514
#
#
# tau=17.328679513998633
#
#
# Relations for 9995 in embedding using distance metric
# 1 1.000000002054426
# 9994 1.0691142363853572
# 9996 1.0691142396362565
# 9993 1.1491142279076445
# 9997 1.1491142329411144
#
#
# tau=17.328679513998633
#
#
# Relations for 9996 in embedding using distance metric
# 1 0.9999999963110154
# 9997 1.0691142336731991
# 9995 1.0691142396362565
# 9994 1.1491142241664514
# 9998 1.1491142313004303
#
#
# tau=17.328679513998633
#
#
# Relations for 9997 in embedding using distance metric
# 1 0.9999999960913688
# 9996 1.0691142336731991
# 9998 1.0691142375562792
# 9999 1.149114231125324
# 9995 1.1491142329411144
#
#
# tau=17.328679513998633
#
#
# Relations for 9998 in embedding using distance metric
# 1 1.0000000001940954
# 9997 1.0691142375562792
# 9999 1.069114241703546
# 9996 1.1491142313004303
# 0 1.1491142349894152
#
#
# tau=17.328679513998633
#
#
# Relations for 9999 in embedding using distance metric
# 1 1.0000000002386356
# 0 1.0691142415094506
# 9998 1.069114241703546
# 9997 1.149114231125324
# 2 1.1491142352725907
